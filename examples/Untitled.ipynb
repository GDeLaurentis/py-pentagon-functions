# %%
import mpmath
import re

from lips import Particles

from pentagon_functions import evaluate_pentagon_functions

# %%
help(evaluate_pentagon_functions)
# Out:
# Help on function evaluate_pentagon_functions in module pentagon_functions:
#
# evaluate_pentagon_functions(pentagon_monomials, phase_space_point, pentagon_function_set='m0', precision='d', number_of_cores=8, verbose=False)
#     Calls PentagonFunctions++ via pyInterface.cpp

# %%
oPs = Particles(6)

# %%
string = """{
{-1.547843350404465913384627373230021512490359482045328048605385476723365048997890367083923854137625`70.,0.170606317783005262530418699838904611635997862746868979012283089933254302252118398150648840081459`70.,1.249321854631455859474719612993553455287228443736914570719868296361625992869843388032310403746115`70.,-0.897723468148218761157431977880753422379335561770435991599901955389876954398844045796133111485775`70.},
{-2.028158032459967161814294145623065084956620513370652173432789863067039349916819449774110253529433`70.,0.201344686003876801802311056831318154847021350535546654238206892174347138093637659786263798471953`70.,1.474413842390593902961805376796266803210471307071325893240412674977502664780181288198624665975723`70.,1.378038150203720009587098750273796994845596593095760116427306341733551255317773128486319510877583`70.},
{1.716617118772343700009342454812543201245371275809472205119779038593411035515251516039765865149305`70.,-0.670063380133598004470410077122799702031289207943541340882000398522401479786816674214142762161674`70.,-1.234655719696509112136241767856891986014172474533593197552309732987053630443997019728614062708599`70.,-0.98661778459892725460094332540199829286685673931218487290565754335608286681600437364552028096801`70.},
{0.824997803458607854638766304762458020461777978378894871574938165211207528919202865493604292965783`70.,-0.233694126241285291267777319267363722469887810540635020709275451315743025098806274593033143745944`70.,-0.780622041979255851423601568594990952416678641955990316619732321839787108122239649784011726911358`70.,0.12898704837303194490943117378097845862560263944111762356933798372927823544948620589263330779443`70.},
{0.940577624481963440307716244505708713516427034989858213884914897879472366398908080464332723099415`70.,0.582003840264901929789865335854797010708878591898458363027636733638571557173912241625926571725177`70.,-0.629743236352375659805373918319225575807061324169900003325902129006939668208490308858713314880448`70.,0.386498711332231841126887524893097518625338322991033272061422004281034505499700245790246854421018`70.},
{0.093808836151518080243096514772376662223403706237754931458543238106313468081347354860331226448418`70.,-0.050197337676900698384407696134856352690720786696697634686850865908028492634045350755663304370715`70.,-0.078714698993909139071307735018711744259787310148756946462336787505348250875297697859595965221746`70.,-0.009182657161837779865042145665121256850345254445290147552506830997904175052111160727546280638917`70.}
}"""

# %%
string = string.replace("`70.", "").replace("{", "[").replace("}", "]").replace("\n", "")
string = re.sub(r"([\d\+\-\.]+)", r"mpmath.mpc('\1')", string)

# %%
four_momenta = eval(string)

# %%
# four_momenta

# %%
for i, oP in enumerate(oPs):
    oP.four_mom = four_momenta[i]

# %%
oPs.phasespace_consistency_check(silent=False);
# Out:
# Consistency check:
# The largest momentum violation is 6.765421556309548e-17
# The largest on shell violation is 1.1102230246251565e-16
# ...

# %%
with open("/home/gdl/Programs/caravel-my-programs/Wjj/quarkspm/pentagon_bases/2loop_nf0.txt", "rb") as f:
    content = f.readlines()

# %%
content
# Out:
# [b'1\n',
#  b'F[1,1]\n',
#  b'F[1,1]*F[1,2]\n',
#  b'F[1,1]*F[1,2]*F[1,3]\n',
#  b'F[1,1]*F[1,2]*F[1,3]*F[1,4]\n',
#  b'F[1,1]*F[1,2]*F[1,3]*F[1,5]\n',
#  b'F[1,1]*F[1,2]*F[1,3]*F[1,6]\n',
#  b'F[1,1]*F[1,2]*F[1,3]*im[1,1]\n',
#  b'F[1,1]*F[1,2]*F[1,3]^2\n',
#  b'F[1,1]*F[1,2]*F[1,4]\n',
#  b'F[1,1]*F[1,2]*F[1,4]*F[1,5]\n',
#  b'F[1,1]*F[1,2]*F[1,4]*F[1,6]\n',
#  b'F[1,1]*F[1,2]*F[1,4]*im[1,1]\n',
#  b'F[1,1]*F[1,2]*F[1,4]^2\n',
#  b'F[1,1]*F[1,2]*F[1,5]\n',
#  b'F[1,1]*F[1,2]*F[1,5]*F[1,6]\n',
#  b'F[1,1]*F[1,2]*F[1,5]*im[1,1]\n',
#  b'F[1,1]*F[1,2]*F[1,5]^2\n',
#  b'F[1,1]*F[1,2]*F[1,6]\n',
#  b'F[1,1]*F[1,2]*F[1,6]*im[1,1]\n',
#  b'F[1,1]*F[1,2]*F[1,6]^2\n',
#  b'F[1,1]*F[1,2]*F[2,3]\n',
#  b'F[1,1]*F[1,2]*F[2,4]\n',
#  b'F[1,1]*F[1,2]*F[2,5]\n',
#  b'F[1,1]*F[1,2]*F[2,6]\n',
#  b'F[1,1]*F[1,2]*F[2,7]\n',
#  b'F[1,1]*F[1,2]*F[2,16]\n',
#  b'F[1,1]*F[1,2]*F[2,17]\n',
#  b'F[1,1]*F[1,2]*im[1,1]\n',
#  b'F[1,1]*F[1,2]*im[1,1]^2\n',
#  b'F[1,1]*F[1,2]^2\n',
#  b'F[1,1]*F[1,2]^2*F[1,3]\n',
#  b'F[1,1]*F[1,2]^2*F[1,4]\n',
#  b'F[1,1]*F[1,2]^2*F[1,5]\n',
#  b'F[1,1]*F[1,2]^2*F[1,6]\n',
#  b'F[1,1]*F[1,2]^2*im[1,1]\n',
#  b'F[1,1]*F[1,2]^3\n',
#  b'F[1,1]*F[1,3]\n',
#  b'F[1,1]*F[1,3]*F[1,4]*F[1,5]\n',
#  b'F[1,1]*F[1,3]*F[1,4]*F[1,6]\n',
#  b'F[1,1]*F[1,3]*F[1,4]*im[1,1]\n',
#  b'F[1,1]*F[1,3]*F[1,4]^2\n',
#  b'F[1,1]*F[1,3]*F[1,5]\n',
#  b'F[1,1]*F[1,3]*F[1,5]*F[1,6]\n',
#  b'F[1,1]*F[1,3]*F[1,5]*im[1,1]\n',
#  b'F[1,1]*F[1,3]*F[1,5]^2\n',
#  b'F[1,1]*F[1,3]*F[1,6]\n',
#  b'F[1,1]*F[1,3]*F[1,6]*im[1,1]\n',
#  b'F[1,1]*F[1,3]*F[1,6]^2\n',
#  b'F[1,1]*F[1,3]*F[2,3]\n',
#  b'F[1,1]*F[1,3]*F[2,4]\n',
#  b'F[1,1]*F[1,3]*F[2,5]\n',
#  b'F[1,1]*F[1,3]*F[2,6]\n',
#  b'F[1,1]*F[1,3]*F[2,7]\n',
#  b'F[1,1]*F[1,3]*F[2,17]\n',
#  b'F[1,1]*F[1,3]*im[1,1]\n',
#  b'F[1,1]*F[1,3]*im[1,1]^2\n',
#  b'F[1,1]*F[1,3]^2\n',
#  b'F[1,1]*F[1,3]^2*F[1,4]\n',
#  b'F[1,1]*F[1,3]^2*F[1,5]\n',
#  b'F[1,1]*F[1,3]^2*F[1,6]\n',
#  b'F[1,1]*F[1,3]^2*im[1,1]\n',
#  b'F[1,1]*F[1,3]^3\n',
#  b'F[1,1]*F[1,4]\n',
#  b'F[1,1]*F[1,4]*F[1,5]\n',
#  b'F[1,1]*F[1,4]*F[1,5]*F[1,6]\n',
#  b'F[1,1]*F[1,4]*F[1,5]*im[1,1]\n',
#  b'F[1,1]*F[1,4]*F[1,5]^2\n',
#  b'F[1,1]*F[1,4]*F[1,6]\n',
#  b'F[1,1]*F[1,4]*F[1,6]*im[1,1]\n',
#  b'F[1,1]*F[1,4]*F[1,6]^2\n',
#  b'F[1,1]*F[1,4]*F[2,3]\n',
#  b'F[1,1]*F[1,4]*F[2,4]\n',
#  b'F[1,1]*F[1,4]*F[2,6]\n',
#  b'F[1,1]*F[1,4]*F[2,7]\n',
#  b'F[1,1]*F[1,4]*F[2,16]\n',
#  b'F[1,1]*F[1,4]*F[2,17]\n',
#  b'F[1,1]*F[1,4]*im[1,1]\n',
#  b'F[1,1]*F[1,4]*im[1,1]^2\n',
#  b'F[1,1]*F[1,4]^2\n',
#  b'F[1,1]*F[1,4]^2*F[1,5]\n',
#  b'F[1,1]*F[1,4]^2*F[1,6]\n',
#  b'F[1,1]*F[1,4]^2*im[1,1]\n',
#  b'F[1,1]*F[1,4]^3\n',
#  b'F[1,1]*F[1,5]\n',
#  b'F[1,1]*F[1,5]*F[1,6]\n',
#  b'F[1,1]*F[1,5]*F[1,6]*im[1,1]\n',
#  b'F[1,1]*F[1,5]*F[1,6]^2\n',
#  b'F[1,1]*F[1,5]*F[2,3]\n',
#  b'F[1,1]*F[1,5]*F[2,4]\n',
#  b'F[1,1]*F[1,5]*F[2,5]\n',
#  b'F[1,1]*F[1,5]*F[2,6]\n',
#  b'F[1,1]*F[1,5]*F[2,7]\n',
#  b'F[1,1]*F[1,5]*F[2,16]\n',
#  b'F[1,1]*F[1,5]*F[2,17]\n',
#  b'F[1,1]*F[1,5]*im[1,1]\n',
#  b'F[1,1]*F[1,5]*im[1,1]^2\n',
#  b'F[1,1]*F[1,5]^2\n',
#  b'F[1,1]*F[1,5]^2*F[1,6]\n',
#  b'F[1,1]*F[1,5]^2*im[1,1]\n',
#  b'F[1,1]*F[1,5]^3\n',
#  b'F[1,1]*F[1,6]\n',
#  b'F[1,1]*F[1,6]*F[2,3]\n',
#  b'F[1,1]*F[1,6]*F[2,4]\n',
#  b'F[1,1]*F[1,6]*F[2,5]\n',
#  b'F[1,1]*F[1,6]*F[2,6]\n',
#  b'F[1,1]*F[1,6]*F[2,7]\n',
#  b'F[1,1]*F[1,6]*F[2,17]\n',
#  b'F[1,1]*F[1,6]*im[1,1]\n',
#  b'F[1,1]*F[1,6]*im[1,1]^2\n',
#  b'F[1,1]*F[1,6]^2\n',
#  b'F[1,1]*F[1,6]^2*im[1,1]\n',
#  b'F[1,1]*F[1,6]^3\n',
#  b'F[1,1]*F[2,3]\n',
#  b'F[1,1]*F[2,3]*im[1,1]\n',
#  b'F[1,1]*F[2,4]\n',
#  b'F[1,1]*F[2,4]*im[1,1]\n',
#  b'F[1,1]*F[2,5]*im[1,1]\n',
#  b'F[1,1]*F[2,6]\n',
#  b'F[1,1]*F[2,6]*im[1,1]\n',
#  b'F[1,1]*F[2,7]\n',
#  b'F[1,1]*F[2,7]*im[1,1]\n',
#  b'F[1,1]*F[2,16]\n',
#  b'F[1,1]*F[2,16]*im[1,1]\n',
#  b'F[1,1]*F[2,17]\n',
#  b'F[1,1]*F[2,17]*im[1,1]\n',
#  b'-str5*F[1,1]*F[3,4]\n',
#  b'F[1,1]*F[3,5]\n',
#  b'F[1,1]*F[3,6]\n',
#  b'F[1,1]*F[3,7]\n',
#  b'F[1,1]*F[3,8]\n',
#  b'F[1,1]*F[3,9]\n',
#  b'F[1,1]*F[3,10]\n',
#  b'F[1,1]*F[3,11]\n',
#  b'F[1,1]*F[3,12]\n',
#  b'F[1,1]*F[3,14]\n',
#  b'F[1,1]*F[3,15]\n',
#  b'F[1,1]*F[3,16]\n',
#  b'F[1,1]*F[3,17]\n',
#  b'F[1,1]*F[3,18]\n',
#  b'F[1,1]*F[3,19]\n',
#  b'F[1,1]*F[3,20]\n',
#  b'F[1,1]*F[3,21]\n',
#  b'F[1,1]*F[3,22]\n',
#  b'F[1,1]*F[3,23]\n',
#  b'F[1,1]*F[3,24]\n',
#  b'F[1,1]*F[3,25]\n',
#  b'F[1,1]*F[3,26]\n',
#  b'F[1,1]*F[3,27]\n',
#  b'F[1,1]*F[3,28]\n',
#  b'F[1,1]*im[1,1]\n',
#  b'F[1,1]*im[1,1]^2\n',
#  b'F[1,1]*im[1,1]^3\n',
#  b'F[1,1]*re[3,1]\n',
#  b'F[1,1]^2\n',
#  b'F[1,1]^2*F[1,2]\n',
#  b'F[1,1]^2*F[1,2]*F[1,3]\n',
#  b'F[1,1]^2*F[1,2]*F[1,4]\n',
#  b'F[1,1]^2*F[1,2]*F[1,5]\n',
#  b'F[1,1]^2*F[1,2]*F[1,6]\n',
#  b'F[1,1]^2*F[1,2]*im[1,1]\n',
#  b'F[1,1]^2*F[1,2]^2\n',
#  b'F[1,1]^2*F[1,3]\n',
#  b'F[1,1]^2*F[1,3]*F[1,4]\n',
#  b'F[1,1]^2*F[1,3]*F[1,5]\n',
#  b'F[1,1]^2*F[1,3]*F[1,6]\n',
#  b'F[1,1]^2*F[1,3]*im[1,1]\n',
#  b'F[1,1]^2*F[1,3]^2\n',
#  b'F[1,1]^2*F[1,4]\n',
#  b'F[1,1]^2*F[1,4]*F[1,5]\n',
#  b'F[1,1]^2*F[1,4]*F[1,6]\n',
#  b'F[1,1]^2*F[1,4]*im[1,1]\n',
#  b'F[1,1]^2*F[1,4]^2\n',
#  b'F[1,1]^2*F[1,5]\n',
#  b'F[1,1]^2*F[1,5]*F[1,6]\n',
#  b'F[1,1]^2*F[1,5]*im[1,1]\n',
#  b'F[1,1]^2*F[1,5]^2\n',
#  b'F[1,1]^2*F[1,6]\n',
#  b'F[1,1]^2*F[1,6]*im[1,1]\n',
#  b'F[1,1]^2*F[1,6]^2\n',
#  b'F[1,1]^2*F[2,3]\n',
#  b'F[1,1]^2*F[2,4]\n',
#  b'F[1,1]^2*F[2,5]\n',
#  b'F[1,1]^2*F[2,6]\n',
#  b'F[1,1]^2*F[2,7]\n',
#  b'F[1,1]^2*F[2,16]\n',
#  b'F[1,1]^2*im[1,1]\n',
#  b'F[1,1]^2*im[1,1]^2\n',
#  b'F[1,1]^3\n',
#  b'F[1,1]^3*F[1,2]\n',
#  b'F[1,1]^3*F[1,3]\n',
#  b'F[1,1]^3*F[1,4]\n',
#  b'F[1,1]^3*F[1,5]\n',
#  b'F[1,1]^3*F[1,6]\n',
#  b'F[1,1]^3*im[1,1]\n',
#  b'F[1,1]^4\n',
#  b'F[1,2]\n',
#  b'F[1,2]*F[1,3]\n',
#  b'F[1,2]*F[1,3]*F[1,4]*F[1,5]\n',
#  b'F[1,2]*F[1,3]*F[1,4]*F[1,6]\n',
#  b'F[1,2]*F[1,3]*F[1,4]*im[1,1]\n',
#  b'F[1,2]*F[1,3]*F[1,4]^2\n',
#  b'F[1,2]*F[1,3]*F[1,5]\n',
#  b'F[1,2]*F[1,3]*F[1,5]*F[1,6]\n',
#  b'F[1,2]*F[1,3]*F[1,5]*im[1,1]\n',
#  b'F[1,2]*F[1,3]*F[1,5]^2\n',
#  b'F[1,2]*F[1,3]*F[1,6]\n',
#  b'F[1,2]*F[1,3]*F[1,6]*im[1,1]\n',
#  b'F[1,2]*F[1,3]*F[1,6]^2\n',
#  b'F[1,2]*F[1,3]*F[2,3]\n',
#  b'F[1,2]*F[1,3]*F[2,4]\n',
#  b'F[1,2]*F[1,3]*F[2,5]\n',
#  b'F[1,2]*F[1,3]*F[2,6]\n',
#  b'F[1,2]*F[1,3]*F[2,17]\n',
#  b'F[1,2]*F[1,3]*im[1,1]\n',
#  b'F[1,2]*F[1,3]*im[1,1]^2\n',
#  b'F[1,2]*F[1,3]^2\n',
#  b'F[1,2]*F[1,3]^2*F[1,4]\n',
#  b'F[1,2]*F[1,3]^2*F[1,5]\n',
#  b'F[1,2]*F[1,3]^2*F[1,6]\n',
#  b'F[1,2]*F[1,3]^2*im[1,1]\n',
#  b'F[1,2]*F[1,3]^3\n',
#  b'F[1,2]*F[1,4]\n',
#  b'F[1,2]*F[1,4]*F[1,5]\n',
#  b'F[1,2]*F[1,4]*F[1,5]*F[1,6]\n',
#  b'F[1,2]*F[1,4]*F[1,5]*im[1,1]\n',
#  b'F[1,2]*F[1,4]*F[1,5]^2\n',
#  b'F[1,2]*F[1,4]*F[1,6]\n',
#  b'F[1,2]*F[1,4]*F[1,6]*im[1,1]\n',
#  b'F[1,2]*F[1,4]*F[1,6]^2\n',
#  b'F[1,2]*F[1,4]*F[2,4]\n',
#  b'F[1,2]*F[1,4]*F[2,6]\n',
#  b'F[1,2]*F[1,4]*F[2,7]\n',
#  b'F[1,2]*F[1,4]*F[2,16]\n',
#  b'F[1,2]*F[1,4]*F[2,17]\n',
#  b'F[1,2]*F[1,4]*im[1,1]\n',
#  b'F[1,2]*F[1,4]*im[1,1]^2\n',
#  b'F[1,2]*F[1,4]^2\n',
#  b'F[1,2]*F[1,4]^2*F[1,5]\n',
#  b'F[1,2]*F[1,4]^2*F[1,6]\n',
#  b'F[1,2]*F[1,4]^2*im[1,1]\n',
#  b'F[1,2]*F[1,4]^3\n',
#  b'F[1,2]*F[1,5]\n',
#  b'F[1,2]*F[1,5]*F[1,6]\n',
#  b'F[1,2]*F[1,5]*F[1,6]*im[1,1]\n',
#  b'F[1,2]*F[1,5]*F[1,6]^2\n',
#  b'F[1,2]*F[1,5]*F[2,4]\n',
#  b'F[1,2]*F[1,5]*F[2,5]\n',
#  b'F[1,2]*F[1,5]*F[2,6]\n',
#  b'F[1,2]*F[1,5]*F[2,7]\n',
#  b'F[1,2]*F[1,5]*F[2,16]\n',
#  b'F[1,2]*F[1,5]*F[2,17]\n',
#  b'F[1,2]*F[1,5]*im[1,1]\n',
#  b'F[1,2]*F[1,5]*im[1,1]^2\n',
#  b'F[1,2]*F[1,5]^2\n',
#  b'F[1,2]*F[1,5]^2*F[1,6]\n',
#  b'F[1,2]*F[1,5]^2*im[1,1]\n',
#  b'F[1,2]*F[1,5]^3\n',
#  b'F[1,2]*F[1,6]\n',
#  b'F[1,2]*F[1,6]*F[2,4]\n',
#  b'F[1,2]*F[1,6]*F[2,5]\n',
#  b'F[1,2]*F[1,6]*F[2,6]\n',
#  b'F[1,2]*F[1,6]*F[2,7]\n',
#  b'F[1,2]*F[1,6]*F[2,16]\n',
#  b'F[1,2]*F[1,6]*F[2,17]\n',
#  b'F[1,2]*F[1,6]*im[1,1]\n',
#  b'F[1,2]*F[1,6]*im[1,1]^2\n',
#  b'F[1,2]*F[1,6]^2\n',
#  b'F[1,2]*F[1,6]^2*im[1,1]\n',
#  b'F[1,2]*F[1,6]^3\n',
#  b'F[1,2]*F[2,3]\n',
#  b'F[1,2]*F[2,3]*im[1,1]\n',
#  b'F[1,2]*F[2,4]\n',
#  b'F[1,2]*F[2,4]*im[1,1]\n',
#  b'F[1,2]*F[2,5]*im[1,1]\n',
#  b'F[1,2]*F[2,6]\n',
#  b'F[1,2]*F[2,6]*im[1,1]\n',
#  b'F[1,2]*F[2,7]*im[1,1]\n',
#  b'F[1,2]*F[2,16]\n',
#  b'F[1,2]*F[2,16]*im[1,1]\n',
#  b'F[1,2]*F[2,17]\n',
#  b'F[1,2]*F[2,17]*im[1,1]\n',
#  b'-str5*F[1,2]*F[3,4]\n',
#  b'F[1,2]*F[3,5]\n',
#  b'F[1,2]*F[3,6]\n',
#  b'F[1,2]*F[3,7]\n',
#  b'F[1,2]*F[3,8]\n',
#  b'F[1,2]*F[3,9]\n',
#  b'F[1,2]*F[3,10]\n',
#  b'F[1,2]*F[3,11]\n',
#  b'F[1,2]*F[3,12]\n',
#  b'F[1,2]*F[3,13]\n',
#  b'F[1,2]*F[3,14]\n',
#  b'F[1,2]*F[3,15]\n',
#  b'F[1,2]*F[3,16]\n',
#  b'F[1,2]*F[3,17]\n',
#  b'F[1,2]*F[3,18]\n',
#  b'F[1,2]*F[3,19]\n',
#  b'F[1,2]*F[3,20]\n',
#  b'F[1,2]*F[3,21]\n',
#  b'F[1,2]*F[3,22]\n',
#  b'F[1,2]*F[3,23]\n',
#  b'F[1,2]*F[3,24]\n',
#  b'F[1,2]*F[3,25]\n',
#  b'F[1,2]*F[3,26]\n',
#  b'F[1,2]*F[3,27]\n',
#  b'F[1,2]*F[3,28]\n',
#  b'F[1,2]*F[3,30]\n',
#  b'F[1,2]*F[3,31]\n',
#  b'F[1,2]*im[1,1]\n',
#  b'F[1,2]*im[1,1]^2\n',
#  b'F[1,2]*im[1,1]^3\n',
#  b'F[1,2]*re[3,1]\n',
#  b'F[1,2]^2\n',
#  b'F[1,2]^2*F[1,3]\n',
#  b'F[1,2]^2*F[1,3]*F[1,4]\n',
#  b'F[1,2]^2*F[1,3]*F[1,5]\n',
#  b'F[1,2]^2*F[1,3]*F[1,6]\n',
#  b'F[1,2]^2*F[1,3]*im[1,1]\n',
#  b'F[1,2]^2*F[1,3]^2\n',
#  b'F[1,2]^2*F[1,4]\n',
#  b'F[1,2]^2*F[1,4]*F[1,5]\n',
#  b'F[1,2]^2*F[1,4]*F[1,6]\n',
#  b'F[1,2]^2*F[1,4]*im[1,1]\n',
#  b'F[1,2]^2*F[1,4]^2\n',
#  b'F[1,2]^2*F[1,5]\n',
#  b'F[1,2]^2*F[1,5]*F[1,6]\n',
#  b'F[1,2]^2*F[1,5]*im[1,1]\n',
#  b'F[1,2]^2*F[1,5]^2\n',
#  b'F[1,2]^2*F[1,6]\n',
#  b'F[1,2]^2*F[1,6]*im[1,1]\n',
#  b'F[1,2]^2*F[1,6]^2\n',
#  b'F[1,2]^2*F[2,4]\n',
#  b'F[1,2]^2*F[2,5]\n',
#  b'F[1,2]^2*F[2,6]\n',
#  b'F[1,2]^2*F[2,7]\n',
#  b'F[1,2]^2*F[2,16]\n',
#  b'F[1,2]^2*F[2,17]\n',
#  b'F[1,2]^2*im[1,1]\n',
#  b'F[1,2]^2*im[1,1]^2\n',
#  b'F[1,2]^3\n',
#  b'F[1,2]^3*F[1,3]\n',
#  b'F[1,2]^3*F[1,4]\n',
#  b'F[1,2]^3*F[1,5]\n',
#  b'F[1,2]^3*F[1,6]\n',
#  b'F[1,2]^3*im[1,1]\n',
#  b'F[1,2]^4\n',
#  b'F[1,3]\n',
#  b'F[1,3]*F[1,4]*F[1,5]*F[1,6]\n',
#  b'F[1,3]*F[1,4]*F[1,5]*im[1,1]\n',
#  b'F[1,3]*F[1,4]*F[1,5]^2\n',
#  b'F[1,3]*F[1,4]*F[1,6]*im[1,1]\n',
#  b'F[1,3]*F[1,4]*F[1,6]^2\n',
#  b'F[1,3]*F[1,4]*F[2,3]\n',
#  b'F[1,3]*F[1,4]*F[2,4]\n',
#  b'F[1,3]*F[1,4]*F[2,5]\n',
#  b'F[1,3]*F[1,4]*F[2,6]\n',
#  b'F[1,3]*F[1,4]*F[2,7]\n',
#  b'F[1,3]*F[1,4]*F[2,17]\n',
#  b'F[1,3]*F[1,4]*im[1,1]^2\n',
#  b'F[1,3]*F[1,4]^2*F[1,5]\n',
#  b'F[1,3]*F[1,4]^2*F[1,6]\n',
#  b'F[1,3]*F[1,4]^2*im[1,1]\n',
#  b'F[1,3]*F[1,4]^3\n',
#  b'F[1,3]*F[1,5]\n',
#  b'F[1,3]*F[1,5]*F[1,6]\n',
#  b'F[1,3]*F[1,5]*F[1,6]*im[1,1]\n',
#  b'F[1,3]*F[1,5]*F[1,6]^2\n',
#  b'F[1,3]*F[1,5]*F[2,3]\n',
#  b'F[1,3]*F[1,5]*F[2,4]\n',
#  b'F[1,3]*F[1,5]*F[2,5]\n',
#  b'F[1,3]*F[1,5]*F[2,6]\n',
#  b'F[1,3]*F[1,5]*F[2,7]\n',
#  b'F[1,3]*F[1,5]*F[2,17]\n',
#  b'F[1,3]*F[1,5]*im[1,1]\n',
#  b'F[1,3]*F[1,5]*im[1,1]^2\n',
#  b'F[1,3]*F[1,5]^2\n',
#  b'F[1,3]*F[1,5]^2*F[1,6]\n',
#  b'F[1,3]*F[1,5]^2*im[1,1]\n',
#  b'F[1,3]*F[1,5]^3\n',
#  b'F[1,3]*F[1,6]\n',
#  b'F[1,3]*F[1,6]*F[2,3]\n',
#  b'F[1,3]*F[1,6]*F[2,4]\n',
#  b'F[1,3]*F[1,6]*F[2,5]\n',
#  b'F[1,3]*F[1,6]*F[2,6]\n',
#  b'F[1,3]*F[1,6]*F[2,7]\n',
#  b'F[1,3]*F[1,6]*F[2,17]\n',
#  b'F[1,3]*F[1,6]*im[1,1]\n',
#  b'F[1,3]*F[1,6]*im[1,1]^2\n',
#  b'F[1,3]*F[1,6]^2\n',
#  b'F[1,3]*F[1,6]^2*im[1,1]\n',
#  b'F[1,3]*F[1,6]^3\n',
#  b'F[1,3]*F[2,3]\n',
#  b'F[1,3]*F[2,3]*im[1,1]\n',
#  b'F[1,3]*F[2,4]*im[1,1]\n',
#  b'F[1,3]*F[2,5]\n',
#  b'F[1,3]*F[2,5]*im[1,1]\n',
#  b'F[1,3]*F[2,6]\n',
#  b'F[1,3]*F[2,6]*im[1,1]\n',
#  b'F[1,3]*F[2,7]*im[1,1]\n',
#  b'F[1,3]*F[2,17]\n',
#  b'F[1,3]*F[2,17]*im[1,1]\n',
#  b'F[1,3]*F[3,5]\n',
#  b'F[1,3]*F[3,6]\n',
#  b'F[1,3]*F[3,7]\n',
#  b'F[1,3]*F[3,8]\n',
#  b'F[1,3]*F[3,9]\n',
#  b'F[1,3]*F[3,10]\n',
#  b'F[1,3]*F[3,11]\n',
#  b'F[1,3]*F[3,12]\n',
#  b'F[1,3]*F[3,14]\n',
#  b'F[1,3]*F[3,15]\n',
#  b'F[1,3]*F[3,16]\n',
#  b'F[1,3]*F[3,17]\n',
#  b'F[1,3]*F[3,18]\n',
#  b'F[1,3]*F[3,19]\n',
#  b'F[1,3]*F[3,20]\n',
#  b'F[1,3]*F[3,21]\n',
#  b'F[1,3]*F[3,22]\n',
#  b'F[1,3]*F[3,23]\n',
#  b'F[1,3]*F[3,24]\n',
#  b'F[1,3]*F[3,25]\n',
#  b'F[1,3]*F[3,26]\n',
#  b'F[1,3]*F[3,27]\n',
#  b'F[1,3]*F[3,28]\n',
#  b'F[1,3]*im[1,1]\n',
#  b'F[1,3]*im[1,1]^2\n',
#  b'F[1,3]*im[1,1]^3\n',
#  b'F[1,3]*re[3,1]\n',
#  b'F[1,3]^2\n',
#  b'F[1,3]^2*F[1,4]*F[1,5]\n',
#  b'F[1,3]^2*F[1,4]*F[1,6]\n',
#  b'F[1,3]^2*F[1,4]*im[1,1]\n',
#  b'F[1,3]^2*F[1,5]\n',
#  b'F[1,3]^2*F[1,5]*F[1,6]\n',
#  b'F[1,3]^2*F[1,5]*im[1,1]\n',
#  b'F[1,3]^2*F[1,5]^2\n',
#  b'F[1,3]^2*F[1,6]\n',
#  b'F[1,3]^2*F[1,6]*im[1,1]\n',
#  b'F[1,3]^2*F[1,6]^2\n',
#  b'F[1,3]^2*F[2,3]\n',
#  b'F[1,3]^2*F[2,5]\n',
#  b'F[1,3]^2*F[2,6]\n',
#  b'F[1,3]^2*F[2,17]\n',
#  b'F[1,3]^2*im[1,1]\n',
#  b'F[1,3]^2*im[1,1]^2\n',
#  b'F[1,3]^3\n',
#  b'F[1,3]^3*F[1,4]\n',
#  b'F[1,3]^3*F[1,5]\n',
#  b'F[1,3]^3*F[1,6]\n',
#  b'F[1,3]^3*im[1,1]\n',
#  b'F[1,3]^4\n',
#  b'F[1,4]\n',
#  b'F[1,4]*F[1,5]\n',
#  b'F[1,4]*F[1,5]*F[1,6]\n',
#  b'F[1,4]*F[1,5]*F[1,6]*im[1,1]\n',
#  b'F[1,4]*F[1,5]*F[1,6]^2\n',
#  b'F[1,4]*F[1,5]*F[2,4]\n',
#  b'F[1,4]*F[1,5]*F[2,6]\n',
#  b'F[1,4]*F[1,5]*F[2,7]\n',
#  b'F[1,4]*F[1,5]*F[2,16]\n',
#  b'F[1,4]*F[1,5]*F[2,17]\n',
#  b'F[1,4]*F[1,5]*im[1,1]\n',
#  b'F[1,4]*F[1,5]*im[1,1]^2\n',
#  b'F[1,4]*F[1,5]^2\n',
#  b'F[1,4]*F[1,5]^2*F[1,6]\n',
#  b'F[1,4]*F[1,5]^2*im[1,1]\n',
#  b'F[1,4]*F[1,5]^3\n',
#  b'F[1,4]*F[1,6]\n',
#  b'F[1,4]*F[1,6]*F[2,4]\n',
#  b'F[1,4]*F[1,6]*F[2,5]\n',
#  b'F[1,4]*F[1,6]*F[2,6]\n',
#  b'F[1,4]*F[1,6]*F[2,7]\n',
#  b'F[1,4]*F[1,6]*F[2,16]\n',
#  b'F[1,4]*F[1,6]*F[2,17]\n',
#  b'F[1,4]*F[1,6]*im[1,1]\n',
#  b'F[1,4]*F[1,6]*im[1,1]^2\n',
#  b'F[1,4]*F[1,6]^2\n',
#  b'F[1,4]*F[1,6]^2*im[1,1]\n',
#  b'F[1,4]*F[1,6]^3\n',
#  b'F[1,4]*F[2,3]*im[1,1]\n',
#  b'F[1,4]*F[2,4]\n',
#  b'F[1,4]*F[2,4]*im[1,1]\n',
#  b'F[1,4]*F[2,5]*im[1,1]\n',
#  b'F[1,4]*F[2,6]*im[1,1]\n',
#  b'F[1,4]*F[2,7]\n',
#  b'F[1,4]*F[2,7]*im[1,1]\n',
#  b'F[1,4]*F[2,16]\n',
#  b'F[1,4]*F[2,16]*im[1,1]\n',
#  b'F[1,4]*F[2,17]\n',
#  b'F[1,4]*F[2,17]*im[1,1]\n',
#  b'F[1,4]*F[3,5]\n',
#  b'F[1,4]*F[3,6]\n',
#  b'F[1,4]*F[3,7]\n',
#  b'F[1,4]*F[3,8]\n',
#  b'F[1,4]*F[3,9]\n',
#  b'F[1,4]*F[3,10]\n',
#  b'F[1,4]*F[3,11]\n',
#  b'F[1,4]*F[3,12]\n',
#  b'F[1,4]*F[3,13]\n',
#  b'F[1,4]*F[3,14]\n',
#  b'F[1,4]*F[3,15]\n',
#  b'F[1,4]*F[3,16]\n',
#  b'F[1,4]*F[3,17]\n',
#  b'F[1,4]*F[3,18]\n',
#  b'F[1,4]*F[3,19]\n',
#  b'F[1,4]*F[3,20]\n',
#  b'F[1,4]*F[3,21]\n',
#  b'F[1,4]*F[3,22]\n',
#  b'F[1,4]*F[3,23]\n',
#  b'F[1,4]*F[3,24]\n',
#  b'F[1,4]*F[3,25]\n',
#  b'F[1,4]*F[3,26]\n',
#  b'F[1,4]*F[3,27]\n',
#  b'F[1,4]*F[3,28]\n',
#  b'F[1,4]*F[3,30]\n',
#  b'F[1,4]*F[3,31]\n',
#  b'F[1,4]*im[1,1]\n',
#  b'F[1,4]*im[1,1]^2\n',
#  b'F[1,4]*im[1,1]^3\n',
#  b'F[1,4]*re[3,1]\n',
#  b'F[1,4]^2\n',
#  b'F[1,4]^2*F[1,5]\n',
#  b'F[1,4]^2*F[1,5]*F[1,6]\n',
#  b'F[1,4]^2*F[1,5]*im[1,1]\n',
#  b'F[1,4]^2*F[1,5]^2\n',
#  b'F[1,4]^2*F[1,6]\n',
#  b'F[1,4]^2*F[1,6]*im[1,1]\n',
#  b'F[1,4]^2*F[1,6]^2\n',
#  b'F[1,4]^2*F[2,4]\n',
#  b'F[1,4]^2*F[2,7]\n',
#  b'F[1,4]^2*F[2,16]\n',
#  b'F[1,4]^2*F[2,17]\n',
#  b'F[1,4]^2*im[1,1]\n',
#  b'F[1,4]^2*im[1,1]^2\n',
#  b'F[1,4]^3\n',
#  b'F[1,4]^3*F[1,5]\n',
#  b'F[1,4]^3*F[1,6]\n',
#  b'F[1,4]^3*im[1,1]\n',
#  b'F[1,4]^4\n',
#  b'F[1,5]\n',
#  b'F[1,5]*F[1,6]\n',
#  b'F[1,5]*F[1,6]*F[2,3]\n',
#  b'F[1,5]*F[1,6]*F[2,4]\n',
#  b'F[1,5]*F[1,6]*F[2,5]\n',
#  b'F[1,5]*F[1,6]*F[2,6]\n',
#  b'F[1,5]*F[1,6]*F[2,7]\n',
#  b'F[1,5]*F[1,6]*F[2,17]\n',
#  b'F[1,5]*F[1,6]*im[1,1]\n',
#  b'F[1,5]*F[1,6]*im[1,1]^2\n',
#  b'F[1,5]*F[1,6]^2\n',
#  b'F[1,5]*F[1,6]^2*im[1,1]\n',
#  b'F[1,5]*F[1,6]^3\n',
#  b'F[1,5]*F[2,3]\n',
#  b'F[1,5]*F[2,3]*im[1,1]\n',
#  b'F[1,5]*F[2,4]\n',
#  b'F[1,5]*F[2,4]*im[1,1]\n',
#  b'F[1,5]*F[2,5]*im[1,1]\n',
#  b'F[1,5]*F[2,6]\n',
#  b'F[1,5]*F[2,6]*im[1,1]\n',
#  b'F[1,5]*F[2,7]\n',
#  b'F[1,5]*F[2,7]*im[1,1]\n',
#  b'F[1,5]*F[2,16]\n',
#  b'F[1,5]*F[2,16]*im[1,1]\n',
#  b'F[1,5]*F[2,17]\n',
#  b'F[1,5]*F[2,17]*im[1,1]\n',
#  b'F[1,5]*F[3,5]\n',
#  b'F[1,5]*F[3,6]\n',
#  b'F[1,5]*F[3,7]\n',
#  b'F[1,5]*F[3,8]\n',
#  b'F[1,5]*F[3,9]\n',
#  b'F[1,5]*F[3,10]\n',
#  b'F[1,5]*F[3,11]\n',
#  b'F[1,5]*F[3,12]\n',
#  b'F[1,5]*F[3,13]\n',
#  b'F[1,5]*F[3,14]\n',
#  b'F[1,5]*F[3,15]\n',
#  b'F[1,5]*F[3,16]\n',
#  b'F[1,5]*F[3,17]\n',
#  b'F[1,5]*F[3,18]\n',
#  b'F[1,5]*F[3,19]\n',
#  b'F[1,5]*F[3,20]\n',
#  b'F[1,5]*F[3,21]\n',
#  b'F[1,5]*F[3,22]\n',
#  b'F[1,5]*F[3,23]\n',
#  b'F[1,5]*F[3,24]\n',
#  b'F[1,5]*F[3,25]\n',
#  b'F[1,5]*F[3,26]\n',
#  b'F[1,5]*F[3,27]\n',
#  b'F[1,5]*F[3,28]\n',
#  b'F[1,5]*F[3,30]\n',
#  b'F[1,5]*F[3,31]\n',
#  b'F[1,5]*im[1,1]\n',
#  b'F[1,5]*im[1,1]^2\n',
#  b'F[1,5]*im[1,1]^3\n',
#  b'F[1,5]*re[3,1]\n',
#  b'F[1,5]^2\n',
#  b'F[1,5]^2*F[1,6]\n',
#  b'F[1,5]^2*F[1,6]*im[1,1]\n',
#  b'F[1,5]^2*F[1,6]^2\n',
#  b'F[1,5]^2*F[2,3]\n',
#  b'F[1,5]^2*F[2,4]\n',
#  b'F[1,5]^2*F[2,5]\n',
#  b'F[1,5]^2*F[2,6]\n',
#  b'F[1,5]^2*F[2,7]\n',
#  b'F[1,5]^2*F[2,16]\n',
#  b'F[1,5]^2*F[2,17]\n',
#  b'F[1,5]^2*im[1,1]\n',
#  b'F[1,5]^2*im[1,1]^2\n',
#  b'F[1,5]^3\n',
#  b'F[1,5]^3*F[1,6]\n',
#  b'F[1,5]^3*im[1,1]\n',
#  b'F[1,5]^4\n',
#  b'F[1,6]\n',
#  b'F[1,6]*F[2,3]\n',
#  b'F[1,6]*F[2,3]*im[1,1]\n',
#  b'F[1,6]*F[2,4]\n',
#  b'F[1,6]*F[2,4]*im[1,1]\n',
#  b'F[1,6]*F[2,5]\n',
#  b'F[1,6]*F[2,5]*im[1,1]\n',
#  b'F[1,6]*F[2,6]\n',
#  b'F[1,6]*F[2,6]*im[1,1]\n',
#  b'F[1,6]*F[2,7]\n',
#  b'F[1,6]*F[2,7]*im[1,1]\n',
#  b'F[1,6]*F[2,16]\n',
#  b'F[1,6]*F[2,16]*im[1,1]\n',
#  b'F[1,6]*F[2,17]\n',
#  b'F[1,6]*F[2,17]*im[1,1]\n',
#  b'F[1,6]*F[3,5]\n',
#  b'F[1,6]*F[3,6]\n',
#  b'F[1,6]*F[3,7]\n',
#  b'F[1,6]*F[3,8]\n',
#  b'F[1,6]*F[3,9]\n',
#  b'F[1,6]*F[3,10]\n',
#  b'F[1,6]*F[3,11]\n',
#  b'F[1,6]*F[3,12]\n',
#  b'F[1,6]*F[3,14]\n',
#  b'F[1,6]*F[3,15]\n',
#  b'F[1,6]*F[3,16]\n',
#  b'F[1,6]*F[3,17]\n',
#  b'F[1,6]*F[3,18]\n',
#  b'F[1,6]*F[3,19]\n',
#  b'F[1,6]*F[3,20]\n',
#  b'F[1,6]*F[3,21]\n',
#  b'F[1,6]*F[3,22]\n',
#  b'F[1,6]*F[3,23]\n',
#  b'F[1,6]*F[3,24]\n',
#  b'F[1,6]*F[3,25]\n',
#  b'F[1,6]*F[3,26]\n',
#  b'F[1,6]*F[3,27]\n',
#  b'F[1,6]*F[3,28]\n',
#  b'F[1,6]*im[1,1]\n',
#  b'F[1,6]*im[1,1]^2\n',
#  b'F[1,6]*im[1,1]^3\n',
#  b'F[1,6]*re[3,1]\n',
#  b'F[1,6]^2\n',
#  b'F[1,6]^2*F[2,3]\n',
#  b'F[1,6]^2*F[2,4]\n',
#  b'F[1,6]^2*F[2,5]\n',
#  b'F[1,6]^2*F[2,6]\n',
#  b'F[1,6]^2*F[2,7]\n',
#  b'F[1,6]^2*F[2,16]\n',
#  b'F[1,6]^2*F[2,17]\n',
#  b'F[1,6]^2*im[1,1]\n',
#  b'F[1,6]^2*im[1,1]^2\n',
#  b'F[1,6]^3\n',
#  b'F[1,6]^3*im[1,1]\n',
#  b'F[1,6]^4\n',
#  b'F[2,3]\n',
#  b'F[2,3]*F[2,5]\n',
#  b'F[2,3]*im[1,1]\n',
#  b'F[2,3]*im[1,1]^2\n',
#  b'F[2,3]^2\n',
#  b'F[2,4]\n',
#  b'F[2,4]*F[2,7]\n',
#  b'F[2,4]*im[1,1]\n',
#  b'F[2,4]*im[1,1]^2\n',
#  b'F[2,4]^2\n',
#  b'F[2,5]\n',
#  b'F[2,5]*im[1,1]\n',
#  b'F[2,5]*im[1,1]^2\n',
#  b'F[2,5]^2\n',
#  b'F[2,6]\n',
#  b'F[2,6]*im[1,1]\n',
#  b'F[2,6]*im[1,1]^2\n',
#  b'F[2,6]^2\n',
#  b'F[2,7]\n',
#  b'F[2,7]*im[1,1]\n',
#  b'F[2,7]*im[1,1]^2\n',
#  b'F[2,7]^2\n',
#  b'F[2,16]\n',
#  b'F[2,16]*im[1,1]\n',
#  b'F[2,16]*im[1,1]^2\n',
#  b'F[2,16]^2\n',
#  b'F[2,17]\n',
#  b'F[2,17]*im[1,1]\n',
#  b'F[2,17]*im[1,1]^2\n',
#  b'F[2,23]/sqrtG3[1]\n',
#  b'F[2,23]^2\n',
#  b'F[3,1]/sqrtG3[1]\n',
#  b'F[3,2]\n',
#  b'-str5*F[3,4]\n',
#  b'-str5*F[3,4]*im[1,1]\n',
#  b'F[3,5]\n',
#  b'F[3,5]*im[1,1]\n',
#  b'F[3,6]\n',
#  b'F[3,6]*im[1,1]\n',
#  b'F[3,7]\n',
#  b'F[3,7]*im[1,1]\n',
#  b'F[3,8]\n',
#  b'F[3,8]*im[1,1]\n',
#  b'F[3,9]\n',
#  b'F[3,9]*im[1,1]\n',
#  b'F[3,10]\n',
#  b'F[3,10]*im[1,1]\n',
#  b'F[3,11]\n',
#  b'F[3,11]*im[1,1]\n',
#  b'F[3,12]\n',
#  b'F[3,12]*im[1,1]\n',
#  b'F[3,13]\n',
#  b'F[3,13]*im[1,1]\n',
#  b'F[3,14]\n',
#  b'F[3,14]*im[1,1]\n',
#  b'F[3,15]\n',
#  b'F[3,15]*im[1,1]\n',
#  b'F[3,16]\n',
#  b'F[3,16]*im[1,1]\n',
#  b'F[3,17]\n',
#  b'F[3,17]*im[1,1]\n',
#  b'F[3,18]\n',
#  b'F[3,18]*im[1,1]\n',
#  b'F[3,19]\n',
#  b'F[3,19]*im[1,1]\n',
#  b'F[3,20]\n',
#  b'F[3,20]*im[1,1]\n',
#  b'F[3,21]\n',
#  b'F[3,21]*im[1,1]\n',
#  b'F[3,22]\n',
#  b'F[3,22]*im[1,1]\n',
#  b'F[3,23]\n',
#  b'F[3,23]*im[1,1]\n',
#  b'F[3,24]\n',
#  b'F[3,24]*im[1,1]\n',
#  b'F[3,25]\n',
#  b'F[3,25]*im[1,1]\n',
#  b'F[3,26]\n',
#  b'F[3,26]*im[1,1]\n',
#  b'F[3,27]\n',
#  b'F[3,27]*im[1,1]\n',
#  b'F[3,28]\n',
#  b'F[3,28]*im[1,1]\n',
#  b'F[3,29]/sqrtG3[1]\n',
#  b'F[3,30]\n',
#  b'F[3,30]*im[1,1]\n',
#  b'F[3,31]\n',
#  b'F[3,31]*im[1,1]\n',
#  b'F[4,1]\n',
#  b'F[4,2]\n',
#  b'F[4,4]\n',
#  b'F[4,5]\n',
#  b'F[4,6]\n',
#  b'F[4,7]\n',
#  b'F[4,8]\n',
#  b'F[4,9]\n',
#  b'F[4,10]\n',
#  b'F[4,11]\n',
#  b'F[4,13]\n',
#  b'F[4,14]\n',
#  b'F[4,15]\n',
#  b'F[4,16]\n',
#  b'F[4,17]\n',
#  b'F[4,18]\n',
#  b'F[4,19]\n',
#  b'F[4,21]\n',
#  b'F[4,23]\n',
#  b'F[4,24]\n',
#  b'F[4,25]\n',
#  b'F[4,26]\n',
#  b'F[4,27]\n',
#  b'F[4,30]\n',
#  b'F[4,31]\n',
#  b'F[4,32]\n',
#  b'F[4,33]\n',
#  b'F[4,34]\n',
#  b'F[4,35]\n',
#  b'F[4,37]\n',
#  b'F[4,38]\n',
#  b'F[4,39]\n',
#  b'F[4,40]\n',
#  b'F[4,41]\n',
#  b'F[4,42]\n',
#  b'F[4,43]\n',
#  b'F[4,44]\n',
#  b'F[4,48]\n',
#  b'F[4,51]\n',
#  b'-str5*F[4,54]\n',
#  b'F[4,55]\n',
#  b'F[4,57]\n',
#  b'F[4,58]\n',
#  b'F[4,60]\n',
#  b'F[4,61]\n',
#  b'F[4,62]\n',
#  b'F[4,63]\n',
#  b'-str5*F[4,65]\n',
#  b'F[4,66]\n',
#  b'F[4,67]\n',
#  b'F[4,68]\n',
#  b'F[4,69]\n',
#  b'F[4,70]\n',
#  b'F[4,71]/sqrtG3[3]\n',
#  b'F[4,72]\n',
#  b'F[4,73]\n',
#  b'F[4,74]\n',
#  b'F[4,75]\n',
#  b'F[4,76]\n',
#  b'F[4,77]\n',
#  b'F[4,78]\n',
#  b'F[4,79]\n',
#  b'F[4,81]\n',
#  b'F[4,83]\n',
#  b'F[4,84]\n',
#  b'F[4,85]\n',
#  b'F[4,86]\n',
#  b'F[4,87]\n',
#  b'F[4,89]\n',
#  b'F[4,90]\n',
#  b'F[4,91]\n',
#  b'F[4,92]\n',
#  b'F[4,93]\n',
#  b'-str5*F[4,98]\n',
#  b'-str5*F[4,99]\n',
#  b'-str5*F[4,100]\n',
#  b'-str5*F[4,101]\n',
#  b'F[4,102]\n',
#  b'F[4,103]\n',
#  b'F[4,104]\n',
#  b'F[4,105]\n',
#  b'F[4,106]\n',
#  b'im[1,1]\n',
#  b'im[1,1]*re[3,1]\n',
#  b'im[1,1]^2\n',
#  b'im[1,1]^3\n',
#  b'im[1,1]^4\n',
#  b're[3,1]\n']

# %%
pentagon_functions = [entry.decode("utf-8").replace("\n", "") for entry in content]

# %%
pentagon_functions
# Out:
# ['1',
#  'F[1,1]',
#  'F[1,1]*F[1,2]',
#  'F[1,1]*F[1,2]*F[1,3]',
#  'F[1,1]*F[1,2]*F[1,3]*F[1,4]',
#  'F[1,1]*F[1,2]*F[1,3]*F[1,5]',
#  'F[1,1]*F[1,2]*F[1,3]*F[1,6]',
#  'F[1,1]*F[1,2]*F[1,3]*im[1,1]',
#  'F[1,1]*F[1,2]*F[1,3]^2',
#  'F[1,1]*F[1,2]*F[1,4]',
#  'F[1,1]*F[1,2]*F[1,4]*F[1,5]',
#  'F[1,1]*F[1,2]*F[1,4]*F[1,6]',
#  'F[1,1]*F[1,2]*F[1,4]*im[1,1]',
#  'F[1,1]*F[1,2]*F[1,4]^2',
#  'F[1,1]*F[1,2]*F[1,5]',
#  'F[1,1]*F[1,2]*F[1,5]*F[1,6]',
#  'F[1,1]*F[1,2]*F[1,5]*im[1,1]',
#  'F[1,1]*F[1,2]*F[1,5]^2',
#  'F[1,1]*F[1,2]*F[1,6]',
#  'F[1,1]*F[1,2]*F[1,6]*im[1,1]',
#  'F[1,1]*F[1,2]*F[1,6]^2',
#  'F[1,1]*F[1,2]*F[2,3]',
#  'F[1,1]*F[1,2]*F[2,4]',
#  'F[1,1]*F[1,2]*F[2,5]',
#  'F[1,1]*F[1,2]*F[2,6]',
#  'F[1,1]*F[1,2]*F[2,7]',
#  'F[1,1]*F[1,2]*F[2,16]',
#  'F[1,1]*F[1,2]*F[2,17]',
#  'F[1,1]*F[1,2]*im[1,1]',
#  'F[1,1]*F[1,2]*im[1,1]^2',
#  'F[1,1]*F[1,2]^2',
#  'F[1,1]*F[1,2]^2*F[1,3]',
#  'F[1,1]*F[1,2]^2*F[1,4]',
#  'F[1,1]*F[1,2]^2*F[1,5]',
#  'F[1,1]*F[1,2]^2*F[1,6]',
#  'F[1,1]*F[1,2]^2*im[1,1]',
#  'F[1,1]*F[1,2]^3',
#  'F[1,1]*F[1,3]',
#  'F[1,1]*F[1,3]*F[1,4]*F[1,5]',
#  'F[1,1]*F[1,3]*F[1,4]*F[1,6]',
#  'F[1,1]*F[1,3]*F[1,4]*im[1,1]',
#  'F[1,1]*F[1,3]*F[1,4]^2',
#  'F[1,1]*F[1,3]*F[1,5]',
#  'F[1,1]*F[1,3]*F[1,5]*F[1,6]',
#  'F[1,1]*F[1,3]*F[1,5]*im[1,1]',
#  'F[1,1]*F[1,3]*F[1,5]^2',
#  'F[1,1]*F[1,3]*F[1,6]',
#  'F[1,1]*F[1,3]*F[1,6]*im[1,1]',
#  'F[1,1]*F[1,3]*F[1,6]^2',
#  'F[1,1]*F[1,3]*F[2,3]',
#  'F[1,1]*F[1,3]*F[2,4]',
#  'F[1,1]*F[1,3]*F[2,5]',
#  'F[1,1]*F[1,3]*F[2,6]',
#  'F[1,1]*F[1,3]*F[2,7]',
#  'F[1,1]*F[1,3]*F[2,17]',
#  'F[1,1]*F[1,3]*im[1,1]',
#  'F[1,1]*F[1,3]*im[1,1]^2',
#  'F[1,1]*F[1,3]^2',
#  'F[1,1]*F[1,3]^2*F[1,4]',
#  'F[1,1]*F[1,3]^2*F[1,5]',
#  'F[1,1]*F[1,3]^2*F[1,6]',
#  'F[1,1]*F[1,3]^2*im[1,1]',
#  'F[1,1]*F[1,3]^3',
#  'F[1,1]*F[1,4]',
#  'F[1,1]*F[1,4]*F[1,5]',
#  'F[1,1]*F[1,4]*F[1,5]*F[1,6]',
#  'F[1,1]*F[1,4]*F[1,5]*im[1,1]',
#  'F[1,1]*F[1,4]*F[1,5]^2',
#  'F[1,1]*F[1,4]*F[1,6]',
#  'F[1,1]*F[1,4]*F[1,6]*im[1,1]',
#  'F[1,1]*F[1,4]*F[1,6]^2',
#  'F[1,1]*F[1,4]*F[2,3]',
#  'F[1,1]*F[1,4]*F[2,4]',
#  'F[1,1]*F[1,4]*F[2,6]',
#  'F[1,1]*F[1,4]*F[2,7]',
#  'F[1,1]*F[1,4]*F[2,16]',
#  'F[1,1]*F[1,4]*F[2,17]',
#  'F[1,1]*F[1,4]*im[1,1]',
#  'F[1,1]*F[1,4]*im[1,1]^2',
#  'F[1,1]*F[1,4]^2',
#  'F[1,1]*F[1,4]^2*F[1,5]',
#  'F[1,1]*F[1,4]^2*F[1,6]',
#  'F[1,1]*F[1,4]^2*im[1,1]',
#  'F[1,1]*F[1,4]^3',
#  'F[1,1]*F[1,5]',
#  'F[1,1]*F[1,5]*F[1,6]',
#  'F[1,1]*F[1,5]*F[1,6]*im[1,1]',
#  'F[1,1]*F[1,5]*F[1,6]^2',
#  'F[1,1]*F[1,5]*F[2,3]',
#  'F[1,1]*F[1,5]*F[2,4]',
#  'F[1,1]*F[1,5]*F[2,5]',
#  'F[1,1]*F[1,5]*F[2,6]',
#  'F[1,1]*F[1,5]*F[2,7]',
#  'F[1,1]*F[1,5]*F[2,16]',
#  'F[1,1]*F[1,5]*F[2,17]',
#  'F[1,1]*F[1,5]*im[1,1]',
#  'F[1,1]*F[1,5]*im[1,1]^2',
#  'F[1,1]*F[1,5]^2',
#  'F[1,1]*F[1,5]^2*F[1,6]',
#  'F[1,1]*F[1,5]^2*im[1,1]',
#  'F[1,1]*F[1,5]^3',
#  'F[1,1]*F[1,6]',
#  'F[1,1]*F[1,6]*F[2,3]',
#  'F[1,1]*F[1,6]*F[2,4]',
#  'F[1,1]*F[1,6]*F[2,5]',
#  'F[1,1]*F[1,6]*F[2,6]',
#  'F[1,1]*F[1,6]*F[2,7]',
#  'F[1,1]*F[1,6]*F[2,17]',
#  'F[1,1]*F[1,6]*im[1,1]',
#  'F[1,1]*F[1,6]*im[1,1]^2',
#  'F[1,1]*F[1,6]^2',
#  'F[1,1]*F[1,6]^2*im[1,1]',
#  'F[1,1]*F[1,6]^3',
#  'F[1,1]*F[2,3]',
#  'F[1,1]*F[2,3]*im[1,1]',
#  'F[1,1]*F[2,4]',
#  'F[1,1]*F[2,4]*im[1,1]',
#  'F[1,1]*F[2,5]*im[1,1]',
#  'F[1,1]*F[2,6]',
#  'F[1,1]*F[2,6]*im[1,1]',
#  'F[1,1]*F[2,7]',
#  'F[1,1]*F[2,7]*im[1,1]',
#  'F[1,1]*F[2,16]',
#  'F[1,1]*F[2,16]*im[1,1]',
#  'F[1,1]*F[2,17]',
#  'F[1,1]*F[2,17]*im[1,1]',
#  '-str5*F[1,1]*F[3,4]',
#  'F[1,1]*F[3,5]',
#  'F[1,1]*F[3,6]',
#  'F[1,1]*F[3,7]',
#  'F[1,1]*F[3,8]',
#  'F[1,1]*F[3,9]',
#  'F[1,1]*F[3,10]',
#  'F[1,1]*F[3,11]',
#  'F[1,1]*F[3,12]',
#  'F[1,1]*F[3,14]',
#  'F[1,1]*F[3,15]',
#  'F[1,1]*F[3,16]',
#  'F[1,1]*F[3,17]',
#  'F[1,1]*F[3,18]',
#  'F[1,1]*F[3,19]',
#  'F[1,1]*F[3,20]',
#  'F[1,1]*F[3,21]',
#  'F[1,1]*F[3,22]',
#  'F[1,1]*F[3,23]',
#  'F[1,1]*F[3,24]',
#  'F[1,1]*F[3,25]',
#  'F[1,1]*F[3,26]',
#  'F[1,1]*F[3,27]',
#  'F[1,1]*F[3,28]',
#  'F[1,1]*im[1,1]',
#  'F[1,1]*im[1,1]^2',
#  'F[1,1]*im[1,1]^3',
#  'F[1,1]*re[3,1]',
#  'F[1,1]^2',
#  'F[1,1]^2*F[1,2]',
#  'F[1,1]^2*F[1,2]*F[1,3]',
#  'F[1,1]^2*F[1,2]*F[1,4]',
#  'F[1,1]^2*F[1,2]*F[1,5]',
#  'F[1,1]^2*F[1,2]*F[1,6]',
#  'F[1,1]^2*F[1,2]*im[1,1]',
#  'F[1,1]^2*F[1,2]^2',
#  'F[1,1]^2*F[1,3]',
#  'F[1,1]^2*F[1,3]*F[1,4]',
#  'F[1,1]^2*F[1,3]*F[1,5]',
#  'F[1,1]^2*F[1,3]*F[1,6]',
#  'F[1,1]^2*F[1,3]*im[1,1]',
#  'F[1,1]^2*F[1,3]^2',
#  'F[1,1]^2*F[1,4]',
#  'F[1,1]^2*F[1,4]*F[1,5]',
#  'F[1,1]^2*F[1,4]*F[1,6]',
#  'F[1,1]^2*F[1,4]*im[1,1]',
#  'F[1,1]^2*F[1,4]^2',
#  'F[1,1]^2*F[1,5]',
#  'F[1,1]^2*F[1,5]*F[1,6]',
#  'F[1,1]^2*F[1,5]*im[1,1]',
#  'F[1,1]^2*F[1,5]^2',
#  'F[1,1]^2*F[1,6]',
#  'F[1,1]^2*F[1,6]*im[1,1]',
#  'F[1,1]^2*F[1,6]^2',
#  'F[1,1]^2*F[2,3]',
#  'F[1,1]^2*F[2,4]',
#  'F[1,1]^2*F[2,5]',
#  'F[1,1]^2*F[2,6]',
#  'F[1,1]^2*F[2,7]',
#  'F[1,1]^2*F[2,16]',
#  'F[1,1]^2*im[1,1]',
#  'F[1,1]^2*im[1,1]^2',
#  'F[1,1]^3',
#  'F[1,1]^3*F[1,2]',
#  'F[1,1]^3*F[1,3]',
#  'F[1,1]^3*F[1,4]',
#  'F[1,1]^3*F[1,5]',
#  'F[1,1]^3*F[1,6]',
#  'F[1,1]^3*im[1,1]',
#  'F[1,1]^4',
#  'F[1,2]',
#  'F[1,2]*F[1,3]',
#  'F[1,2]*F[1,3]*F[1,4]*F[1,5]',
#  'F[1,2]*F[1,3]*F[1,4]*F[1,6]',
#  'F[1,2]*F[1,3]*F[1,4]*im[1,1]',
#  'F[1,2]*F[1,3]*F[1,4]^2',
#  'F[1,2]*F[1,3]*F[1,5]',
#  'F[1,2]*F[1,3]*F[1,5]*F[1,6]',
#  'F[1,2]*F[1,3]*F[1,5]*im[1,1]',
#  'F[1,2]*F[1,3]*F[1,5]^2',
#  'F[1,2]*F[1,3]*F[1,6]',
#  'F[1,2]*F[1,3]*F[1,6]*im[1,1]',
#  'F[1,2]*F[1,3]*F[1,6]^2',
#  'F[1,2]*F[1,3]*F[2,3]',
#  'F[1,2]*F[1,3]*F[2,4]',
#  'F[1,2]*F[1,3]*F[2,5]',
#  'F[1,2]*F[1,3]*F[2,6]',
#  'F[1,2]*F[1,3]*F[2,17]',
#  'F[1,2]*F[1,3]*im[1,1]',
#  'F[1,2]*F[1,3]*im[1,1]^2',
#  'F[1,2]*F[1,3]^2',
#  'F[1,2]*F[1,3]^2*F[1,4]',
#  'F[1,2]*F[1,3]^2*F[1,5]',
#  'F[1,2]*F[1,3]^2*F[1,6]',
#  'F[1,2]*F[1,3]^2*im[1,1]',
#  'F[1,2]*F[1,3]^3',
#  'F[1,2]*F[1,4]',
#  'F[1,2]*F[1,4]*F[1,5]',
#  'F[1,2]*F[1,4]*F[1,5]*F[1,6]',
#  'F[1,2]*F[1,4]*F[1,5]*im[1,1]',
#  'F[1,2]*F[1,4]*F[1,5]^2',
#  'F[1,2]*F[1,4]*F[1,6]',
#  'F[1,2]*F[1,4]*F[1,6]*im[1,1]',
#  'F[1,2]*F[1,4]*F[1,6]^2',
#  'F[1,2]*F[1,4]*F[2,4]',
#  'F[1,2]*F[1,4]*F[2,6]',
#  'F[1,2]*F[1,4]*F[2,7]',
#  'F[1,2]*F[1,4]*F[2,16]',
#  'F[1,2]*F[1,4]*F[2,17]',
#  'F[1,2]*F[1,4]*im[1,1]',
#  'F[1,2]*F[1,4]*im[1,1]^2',
#  'F[1,2]*F[1,4]^2',
#  'F[1,2]*F[1,4]^2*F[1,5]',
#  'F[1,2]*F[1,4]^2*F[1,6]',
#  'F[1,2]*F[1,4]^2*im[1,1]',
#  'F[1,2]*F[1,4]^3',
#  'F[1,2]*F[1,5]',
#  'F[1,2]*F[1,5]*F[1,6]',
#  'F[1,2]*F[1,5]*F[1,6]*im[1,1]',
#  'F[1,2]*F[1,5]*F[1,6]^2',
#  'F[1,2]*F[1,5]*F[2,4]',
#  'F[1,2]*F[1,5]*F[2,5]',
#  'F[1,2]*F[1,5]*F[2,6]',
#  'F[1,2]*F[1,5]*F[2,7]',
#  'F[1,2]*F[1,5]*F[2,16]',
#  'F[1,2]*F[1,5]*F[2,17]',
#  'F[1,2]*F[1,5]*im[1,1]',
#  'F[1,2]*F[1,5]*im[1,1]^2',
#  'F[1,2]*F[1,5]^2',
#  'F[1,2]*F[1,5]^2*F[1,6]',
#  'F[1,2]*F[1,5]^2*im[1,1]',
#  'F[1,2]*F[1,5]^3',
#  'F[1,2]*F[1,6]',
#  'F[1,2]*F[1,6]*F[2,4]',
#  'F[1,2]*F[1,6]*F[2,5]',
#  'F[1,2]*F[1,6]*F[2,6]',
#  'F[1,2]*F[1,6]*F[2,7]',
#  'F[1,2]*F[1,6]*F[2,16]',
#  'F[1,2]*F[1,6]*F[2,17]',
#  'F[1,2]*F[1,6]*im[1,1]',
#  'F[1,2]*F[1,6]*im[1,1]^2',
#  'F[1,2]*F[1,6]^2',
#  'F[1,2]*F[1,6]^2*im[1,1]',
#  'F[1,2]*F[1,6]^3',
#  'F[1,2]*F[2,3]',
#  'F[1,2]*F[2,3]*im[1,1]',
#  'F[1,2]*F[2,4]',
#  'F[1,2]*F[2,4]*im[1,1]',
#  'F[1,2]*F[2,5]*im[1,1]',
#  'F[1,2]*F[2,6]',
#  'F[1,2]*F[2,6]*im[1,1]',
#  'F[1,2]*F[2,7]*im[1,1]',
#  'F[1,2]*F[2,16]',
#  'F[1,2]*F[2,16]*im[1,1]',
#  'F[1,2]*F[2,17]',
#  'F[1,2]*F[2,17]*im[1,1]',
#  '-str5*F[1,2]*F[3,4]',
#  'F[1,2]*F[3,5]',
#  'F[1,2]*F[3,6]',
#  'F[1,2]*F[3,7]',
#  'F[1,2]*F[3,8]',
#  'F[1,2]*F[3,9]',
#  'F[1,2]*F[3,10]',
#  'F[1,2]*F[3,11]',
#  'F[1,2]*F[3,12]',
#  'F[1,2]*F[3,13]',
#  'F[1,2]*F[3,14]',
#  'F[1,2]*F[3,15]',
#  'F[1,2]*F[3,16]',
#  'F[1,2]*F[3,17]',
#  'F[1,2]*F[3,18]',
#  'F[1,2]*F[3,19]',
#  'F[1,2]*F[3,20]',
#  'F[1,2]*F[3,21]',
#  'F[1,2]*F[3,22]',
#  'F[1,2]*F[3,23]',
#  'F[1,2]*F[3,24]',
#  'F[1,2]*F[3,25]',
#  'F[1,2]*F[3,26]',
#  'F[1,2]*F[3,27]',
#  'F[1,2]*F[3,28]',
#  'F[1,2]*F[3,30]',
#  'F[1,2]*F[3,31]',
#  'F[1,2]*im[1,1]',
#  'F[1,2]*im[1,1]^2',
#  'F[1,2]*im[1,1]^3',
#  'F[1,2]*re[3,1]',
#  'F[1,2]^2',
#  'F[1,2]^2*F[1,3]',
#  'F[1,2]^2*F[1,3]*F[1,4]',
#  'F[1,2]^2*F[1,3]*F[1,5]',
#  'F[1,2]^2*F[1,3]*F[1,6]',
#  'F[1,2]^2*F[1,3]*im[1,1]',
#  'F[1,2]^2*F[1,3]^2',
#  'F[1,2]^2*F[1,4]',
#  'F[1,2]^2*F[1,4]*F[1,5]',
#  'F[1,2]^2*F[1,4]*F[1,6]',
#  'F[1,2]^2*F[1,4]*im[1,1]',
#  'F[1,2]^2*F[1,4]^2',
#  'F[1,2]^2*F[1,5]',
#  'F[1,2]^2*F[1,5]*F[1,6]',
#  'F[1,2]^2*F[1,5]*im[1,1]',
#  'F[1,2]^2*F[1,5]^2',
#  'F[1,2]^2*F[1,6]',
#  'F[1,2]^2*F[1,6]*im[1,1]',
#  'F[1,2]^2*F[1,6]^2',
#  'F[1,2]^2*F[2,4]',
#  'F[1,2]^2*F[2,5]',
#  'F[1,2]^2*F[2,6]',
#  'F[1,2]^2*F[2,7]',
#  'F[1,2]^2*F[2,16]',
#  'F[1,2]^2*F[2,17]',
#  'F[1,2]^2*im[1,1]',
#  'F[1,2]^2*im[1,1]^2',
#  'F[1,2]^3',
#  'F[1,2]^3*F[1,3]',
#  'F[1,2]^3*F[1,4]',
#  'F[1,2]^3*F[1,5]',
#  'F[1,2]^3*F[1,6]',
#  'F[1,2]^3*im[1,1]',
#  'F[1,2]^4',
#  'F[1,3]',
#  'F[1,3]*F[1,4]*F[1,5]*F[1,6]',
#  'F[1,3]*F[1,4]*F[1,5]*im[1,1]',
#  'F[1,3]*F[1,4]*F[1,5]^2',
#  'F[1,3]*F[1,4]*F[1,6]*im[1,1]',
#  'F[1,3]*F[1,4]*F[1,6]^2',
#  'F[1,3]*F[1,4]*F[2,3]',
#  'F[1,3]*F[1,4]*F[2,4]',
#  'F[1,3]*F[1,4]*F[2,5]',
#  'F[1,3]*F[1,4]*F[2,6]',
#  'F[1,3]*F[1,4]*F[2,7]',
#  'F[1,3]*F[1,4]*F[2,17]',
#  'F[1,3]*F[1,4]*im[1,1]^2',
#  'F[1,3]*F[1,4]^2*F[1,5]',
#  'F[1,3]*F[1,4]^2*F[1,6]',
#  'F[1,3]*F[1,4]^2*im[1,1]',
#  'F[1,3]*F[1,4]^3',
#  'F[1,3]*F[1,5]',
#  'F[1,3]*F[1,5]*F[1,6]',
#  'F[1,3]*F[1,5]*F[1,6]*im[1,1]',
#  'F[1,3]*F[1,5]*F[1,6]^2',
#  'F[1,3]*F[1,5]*F[2,3]',
#  'F[1,3]*F[1,5]*F[2,4]',
#  'F[1,3]*F[1,5]*F[2,5]',
#  'F[1,3]*F[1,5]*F[2,6]',
#  'F[1,3]*F[1,5]*F[2,7]',
#  'F[1,3]*F[1,5]*F[2,17]',
#  'F[1,3]*F[1,5]*im[1,1]',
#  'F[1,3]*F[1,5]*im[1,1]^2',
#  'F[1,3]*F[1,5]^2',
#  'F[1,3]*F[1,5]^2*F[1,6]',
#  'F[1,3]*F[1,5]^2*im[1,1]',
#  'F[1,3]*F[1,5]^3',
#  'F[1,3]*F[1,6]',
#  'F[1,3]*F[1,6]*F[2,3]',
#  'F[1,3]*F[1,6]*F[2,4]',
#  'F[1,3]*F[1,6]*F[2,5]',
#  'F[1,3]*F[1,6]*F[2,6]',
#  'F[1,3]*F[1,6]*F[2,7]',
#  'F[1,3]*F[1,6]*F[2,17]',
#  'F[1,3]*F[1,6]*im[1,1]',
#  'F[1,3]*F[1,6]*im[1,1]^2',
#  'F[1,3]*F[1,6]^2',
#  'F[1,3]*F[1,6]^2*im[1,1]',
#  'F[1,3]*F[1,6]^3',
#  'F[1,3]*F[2,3]',
#  'F[1,3]*F[2,3]*im[1,1]',
#  'F[1,3]*F[2,4]*im[1,1]',
#  'F[1,3]*F[2,5]',
#  'F[1,3]*F[2,5]*im[1,1]',
#  'F[1,3]*F[2,6]',
#  'F[1,3]*F[2,6]*im[1,1]',
#  'F[1,3]*F[2,7]*im[1,1]',
#  'F[1,3]*F[2,17]',
#  'F[1,3]*F[2,17]*im[1,1]',
#  'F[1,3]*F[3,5]',
#  'F[1,3]*F[3,6]',
#  'F[1,3]*F[3,7]',
#  'F[1,3]*F[3,8]',
#  'F[1,3]*F[3,9]',
#  'F[1,3]*F[3,10]',
#  'F[1,3]*F[3,11]',
#  'F[1,3]*F[3,12]',
#  'F[1,3]*F[3,14]',
#  'F[1,3]*F[3,15]',
#  'F[1,3]*F[3,16]',
#  'F[1,3]*F[3,17]',
#  'F[1,3]*F[3,18]',
#  'F[1,3]*F[3,19]',
#  'F[1,3]*F[3,20]',
#  'F[1,3]*F[3,21]',
#  'F[1,3]*F[3,22]',
#  'F[1,3]*F[3,23]',
#  'F[1,3]*F[3,24]',
#  'F[1,3]*F[3,25]',
#  'F[1,3]*F[3,26]',
#  'F[1,3]*F[3,27]',
#  'F[1,3]*F[3,28]',
#  'F[1,3]*im[1,1]',
#  'F[1,3]*im[1,1]^2',
#  'F[1,3]*im[1,1]^3',
#  'F[1,3]*re[3,1]',
#  'F[1,3]^2',
#  'F[1,3]^2*F[1,4]*F[1,5]',
#  'F[1,3]^2*F[1,4]*F[1,6]',
#  'F[1,3]^2*F[1,4]*im[1,1]',
#  'F[1,3]^2*F[1,5]',
#  'F[1,3]^2*F[1,5]*F[1,6]',
#  'F[1,3]^2*F[1,5]*im[1,1]',
#  'F[1,3]^2*F[1,5]^2',
#  'F[1,3]^2*F[1,6]',
#  'F[1,3]^2*F[1,6]*im[1,1]',
#  'F[1,3]^2*F[1,6]^2',
#  'F[1,3]^2*F[2,3]',
#  'F[1,3]^2*F[2,5]',
#  'F[1,3]^2*F[2,6]',
#  'F[1,3]^2*F[2,17]',
#  'F[1,3]^2*im[1,1]',
#  'F[1,3]^2*im[1,1]^2',
#  'F[1,3]^3',
#  'F[1,3]^3*F[1,4]',
#  'F[1,3]^3*F[1,5]',
#  'F[1,3]^3*F[1,6]',
#  'F[1,3]^3*im[1,1]',
#  'F[1,3]^4',
#  'F[1,4]',
#  'F[1,4]*F[1,5]',
#  'F[1,4]*F[1,5]*F[1,6]',
#  'F[1,4]*F[1,5]*F[1,6]*im[1,1]',
#  'F[1,4]*F[1,5]*F[1,6]^2',
#  'F[1,4]*F[1,5]*F[2,4]',
#  'F[1,4]*F[1,5]*F[2,6]',
#  'F[1,4]*F[1,5]*F[2,7]',
#  'F[1,4]*F[1,5]*F[2,16]',
#  'F[1,4]*F[1,5]*F[2,17]',
#  'F[1,4]*F[1,5]*im[1,1]',
#  'F[1,4]*F[1,5]*im[1,1]^2',
#  'F[1,4]*F[1,5]^2',
#  'F[1,4]*F[1,5]^2*F[1,6]',
#  'F[1,4]*F[1,5]^2*im[1,1]',
#  'F[1,4]*F[1,5]^3',
#  'F[1,4]*F[1,6]',
#  'F[1,4]*F[1,6]*F[2,4]',
#  'F[1,4]*F[1,6]*F[2,5]',
#  'F[1,4]*F[1,6]*F[2,6]',
#  'F[1,4]*F[1,6]*F[2,7]',
#  'F[1,4]*F[1,6]*F[2,16]',
#  'F[1,4]*F[1,6]*F[2,17]',
#  'F[1,4]*F[1,6]*im[1,1]',
#  'F[1,4]*F[1,6]*im[1,1]^2',
#  'F[1,4]*F[1,6]^2',
#  'F[1,4]*F[1,6]^2*im[1,1]',
#  'F[1,4]*F[1,6]^3',
#  'F[1,4]*F[2,3]*im[1,1]',
#  'F[1,4]*F[2,4]',
#  'F[1,4]*F[2,4]*im[1,1]',
#  'F[1,4]*F[2,5]*im[1,1]',
#  'F[1,4]*F[2,6]*im[1,1]',
#  'F[1,4]*F[2,7]',
#  'F[1,4]*F[2,7]*im[1,1]',
#  'F[1,4]*F[2,16]',
#  'F[1,4]*F[2,16]*im[1,1]',
#  'F[1,4]*F[2,17]',
#  'F[1,4]*F[2,17]*im[1,1]',
#  'F[1,4]*F[3,5]',
#  'F[1,4]*F[3,6]',
#  'F[1,4]*F[3,7]',
#  'F[1,4]*F[3,8]',
#  'F[1,4]*F[3,9]',
#  'F[1,4]*F[3,10]',
#  'F[1,4]*F[3,11]',
#  'F[1,4]*F[3,12]',
#  'F[1,4]*F[3,13]',
#  'F[1,4]*F[3,14]',
#  'F[1,4]*F[3,15]',
#  'F[1,4]*F[3,16]',
#  'F[1,4]*F[3,17]',
#  'F[1,4]*F[3,18]',
#  'F[1,4]*F[3,19]',
#  'F[1,4]*F[3,20]',
#  'F[1,4]*F[3,21]',
#  'F[1,4]*F[3,22]',
#  'F[1,4]*F[3,23]',
#  'F[1,4]*F[3,24]',
#  'F[1,4]*F[3,25]',
#  'F[1,4]*F[3,26]',
#  'F[1,4]*F[3,27]',
#  'F[1,4]*F[3,28]',
#  'F[1,4]*F[3,30]',
#  'F[1,4]*F[3,31]',
#  'F[1,4]*im[1,1]',
#  'F[1,4]*im[1,1]^2',
#  'F[1,4]*im[1,1]^3',
#  'F[1,4]*re[3,1]',
#  'F[1,4]^2',
#  'F[1,4]^2*F[1,5]',
#  'F[1,4]^2*F[1,5]*F[1,6]',
#  'F[1,4]^2*F[1,5]*im[1,1]',
#  'F[1,4]^2*F[1,5]^2',
#  'F[1,4]^2*F[1,6]',
#  'F[1,4]^2*F[1,6]*im[1,1]',
#  'F[1,4]^2*F[1,6]^2',
#  'F[1,4]^2*F[2,4]',
#  'F[1,4]^2*F[2,7]',
#  'F[1,4]^2*F[2,16]',
#  'F[1,4]^2*F[2,17]',
#  'F[1,4]^2*im[1,1]',
#  'F[1,4]^2*im[1,1]^2',
#  'F[1,4]^3',
#  'F[1,4]^3*F[1,5]',
#  'F[1,4]^3*F[1,6]',
#  'F[1,4]^3*im[1,1]',
#  'F[1,4]^4',
#  'F[1,5]',
#  'F[1,5]*F[1,6]',
#  'F[1,5]*F[1,6]*F[2,3]',
#  'F[1,5]*F[1,6]*F[2,4]',
#  'F[1,5]*F[1,6]*F[2,5]',
#  'F[1,5]*F[1,6]*F[2,6]',
#  'F[1,5]*F[1,6]*F[2,7]',
#  'F[1,5]*F[1,6]*F[2,17]',
#  'F[1,5]*F[1,6]*im[1,1]',
#  'F[1,5]*F[1,6]*im[1,1]^2',
#  'F[1,5]*F[1,6]^2',
#  'F[1,5]*F[1,6]^2*im[1,1]',
#  'F[1,5]*F[1,6]^3',
#  'F[1,5]*F[2,3]',
#  'F[1,5]*F[2,3]*im[1,1]',
#  'F[1,5]*F[2,4]',
#  'F[1,5]*F[2,4]*im[1,1]',
#  'F[1,5]*F[2,5]*im[1,1]',
#  'F[1,5]*F[2,6]',
#  'F[1,5]*F[2,6]*im[1,1]',
#  'F[1,5]*F[2,7]',
#  'F[1,5]*F[2,7]*im[1,1]',
#  'F[1,5]*F[2,16]',
#  'F[1,5]*F[2,16]*im[1,1]',
#  'F[1,5]*F[2,17]',
#  'F[1,5]*F[2,17]*im[1,1]',
#  'F[1,5]*F[3,5]',
#  'F[1,5]*F[3,6]',
#  'F[1,5]*F[3,7]',
#  'F[1,5]*F[3,8]',
#  'F[1,5]*F[3,9]',
#  'F[1,5]*F[3,10]',
#  'F[1,5]*F[3,11]',
#  'F[1,5]*F[3,12]',
#  'F[1,5]*F[3,13]',
#  'F[1,5]*F[3,14]',
#  'F[1,5]*F[3,15]',
#  'F[1,5]*F[3,16]',
#  'F[1,5]*F[3,17]',
#  'F[1,5]*F[3,18]',
#  'F[1,5]*F[3,19]',
#  'F[1,5]*F[3,20]',
#  'F[1,5]*F[3,21]',
#  'F[1,5]*F[3,22]',
#  'F[1,5]*F[3,23]',
#  'F[1,5]*F[3,24]',
#  'F[1,5]*F[3,25]',
#  'F[1,5]*F[3,26]',
#  'F[1,5]*F[3,27]',
#  'F[1,5]*F[3,28]',
#  'F[1,5]*F[3,30]',
#  'F[1,5]*F[3,31]',
#  'F[1,5]*im[1,1]',
#  'F[1,5]*im[1,1]^2',
#  'F[1,5]*im[1,1]^3',
#  'F[1,5]*re[3,1]',
#  'F[1,5]^2',
#  'F[1,5]^2*F[1,6]',
#  'F[1,5]^2*F[1,6]*im[1,1]',
#  'F[1,5]^2*F[1,6]^2',
#  'F[1,5]^2*F[2,3]',
#  'F[1,5]^2*F[2,4]',
#  'F[1,5]^2*F[2,5]',
#  'F[1,5]^2*F[2,6]',
#  'F[1,5]^2*F[2,7]',
#  'F[1,5]^2*F[2,16]',
#  'F[1,5]^2*F[2,17]',
#  'F[1,5]^2*im[1,1]',
#  'F[1,5]^2*im[1,1]^2',
#  'F[1,5]^3',
#  'F[1,5]^3*F[1,6]',
#  'F[1,5]^3*im[1,1]',
#  'F[1,5]^4',
#  'F[1,6]',
#  'F[1,6]*F[2,3]',
#  'F[1,6]*F[2,3]*im[1,1]',
#  'F[1,6]*F[2,4]',
#  'F[1,6]*F[2,4]*im[1,1]',
#  'F[1,6]*F[2,5]',
#  'F[1,6]*F[2,5]*im[1,1]',
#  'F[1,6]*F[2,6]',
#  'F[1,6]*F[2,6]*im[1,1]',
#  'F[1,6]*F[2,7]',
#  'F[1,6]*F[2,7]*im[1,1]',
#  'F[1,6]*F[2,16]',
#  'F[1,6]*F[2,16]*im[1,1]',
#  'F[1,6]*F[2,17]',
#  'F[1,6]*F[2,17]*im[1,1]',
#  'F[1,6]*F[3,5]',
#  'F[1,6]*F[3,6]',
#  'F[1,6]*F[3,7]',
#  'F[1,6]*F[3,8]',
#  'F[1,6]*F[3,9]',
#  'F[1,6]*F[3,10]',
#  'F[1,6]*F[3,11]',
#  'F[1,6]*F[3,12]',
#  'F[1,6]*F[3,14]',
#  'F[1,6]*F[3,15]',
#  'F[1,6]*F[3,16]',
#  'F[1,6]*F[3,17]',
#  'F[1,6]*F[3,18]',
#  'F[1,6]*F[3,19]',
#  'F[1,6]*F[3,20]',
#  'F[1,6]*F[3,21]',
#  'F[1,6]*F[3,22]',
#  'F[1,6]*F[3,23]',
#  'F[1,6]*F[3,24]',
#  'F[1,6]*F[3,25]',
#  'F[1,6]*F[3,26]',
#  'F[1,6]*F[3,27]',
#  'F[1,6]*F[3,28]',
#  'F[1,6]*im[1,1]',
#  'F[1,6]*im[1,1]^2',
#  'F[1,6]*im[1,1]^3',
#  'F[1,6]*re[3,1]',
#  'F[1,6]^2',
#  'F[1,6]^2*F[2,3]',
#  'F[1,6]^2*F[2,4]',
#  'F[1,6]^2*F[2,5]',
#  'F[1,6]^2*F[2,6]',
#  'F[1,6]^2*F[2,7]',
#  'F[1,6]^2*F[2,16]',
#  'F[1,6]^2*F[2,17]',
#  'F[1,6]^2*im[1,1]',
#  'F[1,6]^2*im[1,1]^2',
#  'F[1,6]^3',
#  'F[1,6]^3*im[1,1]',
#  'F[1,6]^4',
#  'F[2,3]',
#  'F[2,3]*F[2,5]',
#  'F[2,3]*im[1,1]',
#  'F[2,3]*im[1,1]^2',
#  'F[2,3]^2',
#  'F[2,4]',
#  'F[2,4]*F[2,7]',
#  'F[2,4]*im[1,1]',
#  'F[2,4]*im[1,1]^2',
#  'F[2,4]^2',
#  'F[2,5]',
#  'F[2,5]*im[1,1]',
#  'F[2,5]*im[1,1]^2',
#  'F[2,5]^2',
#  'F[2,6]',
#  'F[2,6]*im[1,1]',
#  'F[2,6]*im[1,1]^2',
#  'F[2,6]^2',
#  'F[2,7]',
#  'F[2,7]*im[1,1]',
#  'F[2,7]*im[1,1]^2',
#  'F[2,7]^2',
#  'F[2,16]',
#  'F[2,16]*im[1,1]',
#  'F[2,16]*im[1,1]^2',
#  'F[2,16]^2',
#  'F[2,17]',
#  'F[2,17]*im[1,1]',
#  'F[2,17]*im[1,1]^2',
#  'F[2,23]/sqrtG3[1]',
#  'F[2,23]^2',
#  'F[3,1]/sqrtG3[1]',
#  'F[3,2]',
#  '-str5*F[3,4]',
#  '-str5*F[3,4]*im[1,1]',
#  'F[3,5]',
#  'F[3,5]*im[1,1]',
#  'F[3,6]',
#  'F[3,6]*im[1,1]',
#  'F[3,7]',
#  'F[3,7]*im[1,1]',
#  'F[3,8]',
#  'F[3,8]*im[1,1]',
#  'F[3,9]',
#  'F[3,9]*im[1,1]',
#  'F[3,10]',
#  'F[3,10]*im[1,1]',
#  'F[3,11]',
#  'F[3,11]*im[1,1]',
#  'F[3,12]',
#  'F[3,12]*im[1,1]',
#  'F[3,13]',
#  'F[3,13]*im[1,1]',
#  'F[3,14]',
#  'F[3,14]*im[1,1]',
#  'F[3,15]',
#  'F[3,15]*im[1,1]',
#  'F[3,16]',
#  'F[3,16]*im[1,1]',
#  'F[3,17]',
#  'F[3,17]*im[1,1]',
#  'F[3,18]',
#  'F[3,18]*im[1,1]',
#  'F[3,19]',
#  'F[3,19]*im[1,1]',
#  'F[3,20]',
#  'F[3,20]*im[1,1]',
#  'F[3,21]',
#  'F[3,21]*im[1,1]',
#  'F[3,22]',
#  'F[3,22]*im[1,1]',
#  'F[3,23]',
#  'F[3,23]*im[1,1]',
#  'F[3,24]',
#  'F[3,24]*im[1,1]',
#  'F[3,25]',
#  'F[3,25]*im[1,1]',
#  'F[3,26]',
#  'F[3,26]*im[1,1]',
#  'F[3,27]',
#  'F[3,27]*im[1,1]',
#  'F[3,28]',
#  'F[3,28]*im[1,1]',
#  'F[3,29]/sqrtG3[1]',
#  'F[3,30]',
#  'F[3,30]*im[1,1]',
#  'F[3,31]',
#  'F[3,31]*im[1,1]',
#  'F[4,1]',
#  'F[4,2]',
#  'F[4,4]',
#  'F[4,5]',
#  'F[4,6]',
#  'F[4,7]',
#  'F[4,8]',
#  'F[4,9]',
#  'F[4,10]',
#  'F[4,11]',
#  'F[4,13]',
#  'F[4,14]',
#  'F[4,15]',
#  'F[4,16]',
#  'F[4,17]',
#  'F[4,18]',
#  'F[4,19]',
#  'F[4,21]',
#  'F[4,23]',
#  'F[4,24]',
#  'F[4,25]',
#  'F[4,26]',
#  'F[4,27]',
#  'F[4,30]',
#  'F[4,31]',
#  'F[4,32]',
#  'F[4,33]',
#  'F[4,34]',
#  'F[4,35]',
#  'F[4,37]',
#  'F[4,38]',
#  'F[4,39]',
#  'F[4,40]',
#  'F[4,41]',
#  'F[4,42]',
#  'F[4,43]',
#  'F[4,44]',
#  'F[4,48]',
#  'F[4,51]',
#  '-str5*F[4,54]',
#  'F[4,55]',
#  'F[4,57]',
#  'F[4,58]',
#  'F[4,60]',
#  'F[4,61]',
#  'F[4,62]',
#  'F[4,63]',
#  '-str5*F[4,65]',
#  'F[4,66]',
#  'F[4,67]',
#  'F[4,68]',
#  'F[4,69]',
#  'F[4,70]',
#  'F[4,71]/sqrtG3[3]',
#  'F[4,72]',
#  'F[4,73]',
#  'F[4,74]',
#  'F[4,75]',
#  'F[4,76]',
#  'F[4,77]',
#  'F[4,78]',
#  'F[4,79]',
#  'F[4,81]',
#  'F[4,83]',
#  'F[4,84]',
#  'F[4,85]',
#  'F[4,86]',
#  'F[4,87]',
#  'F[4,89]',
#  'F[4,90]',
#  'F[4,91]',
#  'F[4,92]',
#  'F[4,93]',
#  '-str5*F[4,98]',
#  '-str5*F[4,99]',
#  '-str5*F[4,100]',
#  '-str5*F[4,101]',
#  'F[4,102]',
#  'F[4,103]',
#  'F[4,104]',
#  'F[4,105]',
#  'F[4,106]',
#  'im[1,1]',
#  'im[1,1]*re[3,1]',
#  'im[1,1]^2',
#  'im[1,1]^3',
#  'im[1,1]^4',
#  're[3,1]']

# %%
pentagon_monomials = [monomial for entry in pentagon_functions for monomial in entry.split("*")]
pentagon_monomials = [monomial if "^" not in monomial else monomial.split("^")[0] for monomial in pentagon_monomials]
pentagon_monomials = list(set(pentagon_monomials))

# %%
pentagon_monomials
# Out:
# ['F[4,41]',
#  'F[3,5]',
#  'F[4,83]',
#  'F[4,106]',
#  'F[2,16]',
#  '-str5',
#  'F[1,4]',
#  'F[4,38]',
#  'F[3,17]',
#  'F[3,30]',
#  'F[4,60]',
#  'F[4,66]',
#  'F[3,22]',
#  'F[4,73]',
#  'F[4,23]',
#  'F[3,2]',
#  'F[3,6]',
#  'F[4,15]',
#  'F[4,25]',
#  'F[3,21]',
#  'F[4,21]',
#  'F[4,33]',
#  'F[4,26]',
#  'F[4,55]',
#  'F[3,15]',
#  'F[4,8]',
#  'F[4,84]',
#  'F[3,18]',
#  'F[4,4]',
#  'F[4,65]',
#  'F[4,19]',
#  'F[3,8]',
#  'F[4,87]',
#  'F[3,31]',
#  'F[4,75]',
#  'F[4,90]',
#  'F[4,81]',
#  'F[3,12]',
#  'F[2,4]',
#  'F[4,2]',
#  'F[4,18]',
#  'F[4,71]/sqrtG3[3]',
#  'F[4,51]',
#  'F[4,31]',
#  'F[2,23]',
#  'F[4,10]',
#  'F[4,37]',
#  'F[4,89]',
#  'F[3,9]',
#  'F[4,57]',
#  'F[3,26]',
#  'F[1,3]',
#  'F[4,9]',
#  'F[4,62]',
#  'F[3,11]',
#  'F[4,98]',
#  'F[2,5]',
#  'F[1,6]',
#  'F[2,3]',
#  'F[3,27]',
#  'F[4,91]',
#  'F[4,99]',
#  'F[4,92]',
#  'F[4,101]',
#  'F[3,10]',
#  'F[4,32]',
#  'F[4,39]',
#  'F[4,42]',
#  'F[4,61]',
#  'F[2,7]',
#  'F[4,69]',
#  'F[3,4]',
#  'F[3,14]',
#  'F[4,78]',
#  'F[4,70]',
#  'F[3,23]',
#  'F[4,13]',
#  'F[4,102]',
#  'F[4,72]',
#  'F[3,28]',
#  're[3,1]',
#  'F[3,20]',
#  'F[1,2]',
#  'F[4,63]',
#  'F[4,27]',
#  'F[4,30]',
#  'F[4,11]',
#  'F[4,44]',
#  'F[4,58]',
#  'F[3,25]',
#  'F[4,100]',
#  'F[4,77]',
#  'F[4,6]',
#  'F[4,34]',
#  'F[4,1]',
#  'F[3,13]',
#  'F[4,85]',
#  '1',
#  'F[2,17]',
#  'F[4,43]',
#  'F[4,16]',
#  'F[4,35]',
#  'F[4,93]',
#  'F[4,105]',
#  'F[1,1]',
#  'F[4,17]',
#  'F[4,104]',
#  'F[4,74]',
#  'F[4,67]',
#  'F[4,79]',
#  'F[4,54]',
#  'F[4,86]',
#  'F[4,40]',
#  'F[4,48]',
#  'F[4,76]',
#  'F[2,6]',
#  'F[3,1]/sqrtG3[1]',
#  'F[3,24]',
#  'F[3,29]/sqrtG3[1]',
#  'F[4,68]',
#  'F[4,103]',
#  'F[4,7]',
#  'F[4,14]',
#  'F[4,5]',
#  'F[4,24]',
#  'F[1,5]',
#  'F[2,23]/sqrtG3[1]',
#  'F[3,19]',
#  'im[1,1]',
#  'F[3,7]',
#  'F[3,16]']

# %%
pentagon_monomials = ['str5']

# %%
evaluate_pentagon_functions(pentagon_monomials, oPs.image(("654321", False)), pentagon_function_set='m1', number_of_cores=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-5a840ec2fe99> in <module>
# ----> 1 evaluate_pentagon_functions(pentagon_monomials, oPs.image(("654321", False)), pentagon_function_set='m1', number_of_cores=2)
#
# ~/Programs/PentagonFunctions-cpp/python_interface/pentagon_functions.py in wrapper(*args, **kwargs)
#      50     @functools.wraps(func)
#      51     def wrapper(*args, **kwargs):
# ---> 52         return func(tuple(args[0]), *args[1:], **kwargs)
#      53     return wrapper
#      54
#
# ~/Programs/PentagonFunctions-cpp/python_interface/pentagon_functions.py in evaluate_pentagon_functions(pentagon_monomials, phase_space_point, pentagon_function_set, precision, number_of_cores, verbose)
#     106     content = content.replace("*I", "j").replace("I*", "1j*").replace("*^", "e").replace("^", "**").replace("{", "").replace("}", "")
#     107     content = re.sub(r"1j\*([\-\+\d\.e]*)", r"\1j", content).replace(" ", "").replace("+-", "-").replace("\n", "")
# --> 108     numerical_result = [mpmath.mpmathify(entry) for entry in content.split(",")]
#     109     numerical_pentagon_dict = dict(zip(pentagon_monomials, numerical_result))
#     110     numerical_pentagon_dict = {**numerical_pentagon_dict, **constants, **{'1': 1}}
#
# ~/Programs/PentagonFunctions-cpp/python_interface/pentagon_functions.py in <listcomp>(.0)
#     106     content = content.replace("*I", "j").replace("I*", "1j*").replace("*^", "e").replace("^", "**").replace("{", "").replace("}", "")
#     107     content = re.sub(r"1j\*([\-\+\d\.e]*)", r"\1j", content).replace(" ", "").replace("+-", "-").replace("\n", "")
# --> 108     numerical_result = [mpmath.mpmathify(entry) for entry in content.split(",")]
#     109     numerical_pentagon_dict = dict(zip(pentagon_monomials, numerical_result))
#     110     numerical_pentagon_dict = {**numerical_pentagon_dict, **constants, **{'1': 1}}
#
# ~/.local/lib/python3.8/site-packages/mpmath/ctx_mp_python.py in convert(ctx, x, strings)
#     667             try: return ctx.make_mpf(from_Decimal(x, prec, rounding))
#     668             except: pass
# --> 669         return ctx._convert_fallback(x, strings)
#     670
#     671     def npconvert(ctx, x):
#
# ~/.local/lib/python3.8/site-packages/mpmath/ctx_mp.py in _convert_fallback(ctx, x, strings)
#     632             else:
#     633                 raise ValueError("can only create mpf from zero-width interval")
# --> 634         raise TypeError("cannot create mpf from " + repr(x))
#     635
#     636     def mpmathify(ctx, *args, **kwargs):
#
# TypeError: cannot create mpf from ''

# %%
with open("/home/gdl/Documents/PaperSources/211007541/anc/fvalues.m", "r") as f:
    content = f.read()

# %%
content
# Out:
# '{{p1s -> 1/7, s12 -> 17/19, s23 -> 11/13, s34 -> -1/3, s45 -> 5, \n  s15 -> -23/29}, \n {F[1, 1] -> \n   -1.9459101490553133051053527434431797296370847295818611884593901499`64., \n  F[1, 2] -> \n   -1.0986122886681096913952452369225257046474905578227494517346943336`64., \n  F[1, 3] -> \n   -0.11122563511022437975949281401472700164917624871338403124072249856`64., \n  F[1, 4] -> \n   -0.23180161405732433637651920055171548705213259908230833692303497412`64., \n  F[1, 5] -> \n   -0.16705408466316619199154386360018930498356109082278994120047780152`64., \n  F[1, 6] -> \n   1.6094379124341003746007593332261876395256013542685177219126478914`64., \n  F[2, 3] -> \n   -2.8422837201120716759985058545216302547043663387311374162450624444`64., \n  F[2, 4] -> \n   0.28064345858928335077187175752325278390276714746496513231127055659`64. + \n    5.9053404363591322211907952656288853870549080163911798122331797275`64.*I, \n  F[2, 5] -> \n   1.118012078605083066097255642282152090867607938721965419769240438`64., \n  F[2, 6] -> \n   -0.65529608010453005566636570826556066398906892617984590654838346512`64. + \n    0.99484691827067423941812036123341293900538850979639843788463100063`64.*\n     I, F[2, 7] -> \n   -0.82144158782253670742536005681815882130446204905186962782000173225`64. + \n    2.077526911278577549973393909755717481663954158903584839284542974`64.*I, \n  F[2, 16] -> \n   0.69692758895692940285089992123842561046304224631304812977605410278`64., \n  F[2, 17] -> \n   -5.0380531727153799991745547734505705244514872082071947373059195602`64., \n  F[2, 23] -> \n   -8.2467820856158081994957071347203102037033915180550342658545950469`64., \n  F[3, 1] -> \n   -1.172911167181767852500767727582631371986253739408576260067941112`64. + \n    42.157038535540520364708377335299790995468056624990151073435761345`64.*I, \n  F[3, 2] -> \n   -30.552704015621772963107694437147461861691820698015018747847744609`64. + \n    46.23097446391993217645208642152031107129195691199014455829245249`64.*I, \n  F[3, 3] -> \n   25.602099295799021149646691328636543856854586161408612308772373569`64. + \n    19.318042992625104604038972316210911392627492289392759244057046293`64.*I, \n  F[3, 4] -> \n   0.1364096252341287178811168427763256880974291026389942953044011013`64. - \n    0.16272016160104368581173425993503759907384892487794574705397136156`64.*\n     I, F[3, 5] -> \n   65.165630328029895682974376382366598113470964757750320282168270646`64. + \n    17.150495126061287003879165577877881021829902351407429931897085526`64.*I, \n  F[3, 6] -> \n   43.952358742609345209894919178512437939709124655093251457775969395`64. + \n    43.309147040183314538593218993330460032468817295616966102088006622`64.*I, \n  F[3, 7] -> \n   32.584239089713363360330449548792755055862465370765011384325378703`64. + \n    38.970680280386763849274476674526190176775053731015771511097455897`64.*I, \n  F[3, 8] -> \n   -31.511107855574867339833765092628835256758420964718620049172080593`64. - \n    3.2587085322675432236349783707835989289301570256241266893642021858`64.*I, \n  F[3, 9] -> \n   10.650574242748198006206188815407446564867569521667025830697528512`64. + \n    6.6635084299334480951253971328075455002677634169501375285823359238`64.*I, \n  F[3, 10] -> \n   18.358724515132409093579068310996685289345298028721993192442548718`64. - \n    6.0427384200993408131976914860697330256804590243097662885168657727`64.*I, \n  F[3, 11] -> \n   -22.53485556985405061372297340555523336383311171040934661729146791`64. - \n    41.598938890820789789165401880457231931954232615363575174154364638`64.*I, \n  F[3, 12] -> \n   13.206254991862153396400021996616724081322764409919273076396406997`64. - \n    17.850481938075319685175063993691894487991998481359689050688111964`64.*I, \n  F[3, 13] -> \n   46.84082019385929540425072652169249444362250439867417951244983612`64. - \n    9.9071248695682172451921078804189467319943599968764460175651770986`64.*I, \n  F[3, 14] -> \n   -23.215085599084609565036308869017929953944905487775024523482403886`64. - \n    9.1 ...

# %%
phase_space_point("s56")
# Out:
# mpc(real='0.1428571428571428492', imag='0.0')

# %%
1/7
# Out:
# 0.14285714285714285

# %%
pentagon_monomials = [monomial for monomial in pentagon_monomials if "F" in monomial]
pentagon_monomials_as_indices = ["{" + ",".join(re.findall("(\d+)", entry)) + "}" for entry in pentagon_monomials]
pentagon_input_string = ";".join(pentagon_monomials_as_indices).replace("{", "").replace("}", "").replace(",", " ") + ";E"

# %%
pentagon_input_string
# Out:
# '1 1;1 1;1 2;1 1;1 2;1 3;1 1;1 2;1 3;1 4;1 1;1 2;1 3;1 5;1 1;1 2;1 3;1 6;1 1;E'

# %%
phase_space_point = oPs

# %%
# 5 pt 1mass notation
p1s, s12, s23, s34, s45, s15 = (phase_space_point("s12"), phase_space_point("s23"), phase_space_point("s34"),
                                phase_space_point("s45"), phase_space_point("s15"))
s12, s23, s34, s45, s15 = [mpmath.mpf(mandel.real) for mandel in [s12, s23, s34, s45, s15]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-8f5a05f08e3f> in <module>
#       1 # 5 pt 1mass notation
# ----> 2 p1s, s12, s23, s34, s45, s15 = (phase_space_point("s12"), phase_space_point("s23"), phase_space_point("s34"),
#       3                                 phase_space_point("s45"), phase_space_point("s15"))
#       4 s12, s23, s34, s45, s15 = [mpmath.mpf(mandel.real) for mandel in [s12, s23, s34, s45, s15]]
#
# ValueError: not enough values to unpack (expected 6, got 5)

# %%
f"{s12} {s23} {s34} {s45} {s15}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-fcb1b6657dfd> in <module>
# ----> 1 f"{s12} {s23} {s34} {s45} {s15}"
#
# NameError: name 's12' is not defined
